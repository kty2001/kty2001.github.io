# %%
import numpy as np

def mean_squared_error(y_true, y_pred):
    return np.mean((y_true - y_pred) ** 2)

# 예제 데이터
y_true = np.array([3.0, -0.5, 2.0, 7.0])
y_pred = np.array([2.5, 0.0, 2.0, 8.0])

mse = mean_squared_error(y_true, y_pred)
print(f"MSE: {mse}")

# %%
def mean_absolute_error(y_true, y_pred):
    return np.mean(np.abs(y_true - y_pred))

mae = mean_absolute_error(y_true, y_pred)
print(f"MAE: {mae}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 def mean_absolute_error(y_true, y_pred):
#       2     return np.mean(np.abs(y_true - y_pred))
#       3
# ----> 4 mae = mean_absolute_error(y_true, y_pred)
#       5 print(f"MAE: {mae}")
#
# NameError: name 'y_true' is not defined

# %%
def huber_loss(y_true, y_pred, delta=1.0):
    error = y_true - y_pred
    is_small_error = np.abs(error) <= delta
    squared_loss = 0.5 * error**2
    linear_loss = delta * (np.abs(error) - 0.5 * delta)
    return np.mean(np.where(is_small_error, squared_loss, linear_loss))

huber = huber_loss(y_true, y_pred)
print(f"Huber Loss: {huber}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 8
#       4     squared_loss = 0.5 * error**2
#       5     linear_loss = delta * (np.abs(error) - 0.5 * delta)
#       6     return np.mean(np.where(is_small_error, squared_loss, linear_loss))
#       7
# ----> 8 huber = huber_loss(y_true, y_pred)
#       9 print(f"Huber Loss: {huber}")
#
# NameError: name 'y_true' is not defined

# %%
def cross_entropy_error(y_true, y_pred):
    delta = 1e-7  # log(0) 방지를 위한 작은 값
    return -np.sum(y_true * np.log(y_pred + delta))

# 예제 데이터 (One-hot encoding)
y_true = np.array([0, 0, 1])  # 실제 정답 (세 번째 클래스)
y_pred = np.array([0.2, 0.3, 0.5])  # 예측 확률

cee = cross_entropy_error(y_true, y_pred)
print(f"CEE: {cee}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2     delta = 1e-7  # log(0) 방지를 위한 작은 값
#       3     return -np.sum(y_true * np.log(y_pred + delta))
#       4
#       5 # 예제 데이터 (One-hot encoding)
# ----> 6 y_true = np.array([0, 0, 1])  # 실제 정답 (세 번째 클래스)
#       7 y_pred = np.array([0.2, 0.3, 0.5])  # 예측 확률
#       8
#       9 cee = cross_entropy_error(y_true, y_pred)
#
# NameError: name 'np' is not defined
