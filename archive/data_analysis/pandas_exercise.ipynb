# %%
import pandas as pd

# %%
# 리스트로 Series 생성
s = pd.Series([10, 20, 30, 40], index=['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age         City
# 0    Alice   25     New York
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
# 특정 열 선택
print(df['Name'])
# Out:
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# Name: Name, dtype: str

# %%
# 특정 열 선택
print(df[['Name']])
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David

# %%
# 특정 행 선택 (인덱스 기준)
print(df.loc[1])  # 두 번째 행 선택
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
print(df.iloc[1])
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object

# %%
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [25, 30, 35, 40],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston']
}

df = pd.DataFrame(data)

# 단일 열 선택
print(df['City'])
# Out:
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# Name: City, dtype: str

# %%
print(df.loc[1])  # 두 번째 행
print(df.iloc[2])  # 세 번째 행
# Out:
# Name            Bob
# Age              30
# City    Los Angeles
# Name: 1, dtype: object
# Name    Charlie
# Age          35
# City    Chicago
# Name: 2, dtype: object

# %%
df['Age'] >= 30
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
df[df['Age'] >= 30]
# Out:
#       Name  Age         City
# 1      Bob   30  Los Angeles
# 2  Charlie   35      Chicago
# 3    David   40      Houston

# %%
df['Country'] = ['USA', 'USA', 'USA', 'USA']
df
# Out:
#       Name  Age         City Country
# 0    Alice   25     New York     USA
# 1      Bob   30  Los Angeles     USA
# 2  Charlie   35      Chicago     USA
# 3    David   40      Houston     USA

# %%
df.loc[4] = ['Eve', 28, 'San Francisco', 'USA']
print(df)
# Out:
#       Name  Age           City Country
# 0    Alice   25       New York     USA
# 1      Bob   30    Los Angeles     USA
# 2  Charlie   35        Chicago     USA
# 3    David   40        Houston     USA
# 4      Eve   28  San Francisco     USA

# %%
# 'Country' 열 삭제
df = df.drop('Country', axis=1)
print(df)
# Out:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
# 0번째 행 삭제
df = df.drop(0)
print(df)
# Out:
#       Name  Age           City
# 1      Bob   30    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
# df.drop(3, inplace=True)
df
# Out:
#       Name  Age           City
# 1      Bob   30    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
df.loc[1, 'Age'] = 31
df
# Out:
#       Name  Age           City
# 1      Bob   31    Los Angeles
# 2  Charlie   35        Chicago
# 3    David   40        Houston
# 4      Eve   28  San Francisco

# %%
# 'Age' 열을 float 타입으로 변경
df['Age'] = df['Age'].astype(float)
print(df.dtypes)
# Out:
# Name        str
# Age     float64
# City        str
# dtype: object

# %%
df
# Out:
#       Name   Age           City
# 1      Bob  31.0    Los Angeles
# 2  Charlie  35.0        Chicago
# 3    David  40.0        Houston
# 4      Eve  28.0  San Francisco

# %%
df_filtered = df[df['Age'] >= 30]
print(df_filtered)
# Out:
#       Name   Age         City
# 1      Bob  31.0  Los Angeles
# 2  Charlie  35.0      Chicago
# 3    David  40.0      Houston

# %%
df_filtered = df[(df['Age'] >= 30) & (df['City'] == 'Chicago')]
print(df_filtered)
# Out:
#       Name   Age     City
# 2  Charlie  35.0  Chicago

# %%
arrays = [
    ['Group1', 'Group1', 'Group2', 'Group2'],
    ['Subgroup1', 'Subgroup2', 'Subgroup1', 'Subgroup2']
]
index = pd.MultiIndex.from_arrays(arrays, names=('Group', 'Subgroup'))

data = {'Value': [10, 20, 30, 40]}
df_multi = pd.DataFrame(data, index=index)
print(df_multi)
# Out:
#                   Value
# Group  Subgroup
# Group1 Subgroup1     10
#        Subgroup2     20
# Group2 Subgroup1     30
#        Subgroup2     40

# %%
# Group1의 데이터 선택
print(df_multi.loc['Group1'])
# Out:
#            Value
# Subgroup
# Subgroup1     10
# Subgroup2     20

# %%
df.loc[2, 'Name']
# Out:
# 'Charlie'

# %%
df.iloc[1, 2]
# Out:
# 'Chicago'

# %%
print(df.at[1, 'Name'])
# Out:
# Bob

# %%
print(df.iat[1, 0])
# Out:
# Charlie

# %%
data = [
    ['Name', 'Age', 'City', 'Salary'],
    ['Alice', 25, 'New York', 70000],
    ['Bob', 30, 'Los Angeles', 80000],
    ['Charlie', 35, 'Chicago', 120000],
    ['David', 40, 'Houston', 90000],
    ['Eve', 28, 'San Francisco', 75000]
]

df = pd.DataFrame(data[1:], columns=data[0])

# %%
df.to_csv('data/data.csv', index=False)
df = pd.read_csv('data/data.csv')
print(df.head())
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df.to_excel('data/output.xlsx', index=False, sheet_name='New Sheet')
df = pd.read_excel('data/output.xlsx', sheet_name='New Sheet')
df
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
df.to_json('data/output.json', index=False)
df = pd.read_json('data/output.json')
print(df.head())
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
from sqlalchemy import create_engine

# SQL 데이터베이스 연결
engine = create_engine('sqlite:///my_database.db')

df.to_sql('my_table', con=engine, if_exists='replace', index=False)

# SQL 쿼리로 데이터 읽기
df = pd.read_sql('SELECT * FROM my_table', con=engine)
print(df.head())
# Out:
#       Name  Age           City  Salary
# 0    Alice   25       New York   70000
# 1      Bob   30    Los Angeles   80000
# 2  Charlie   35        Chicago  120000
# 3    David   40        Houston   90000
# 4      Eve   28  San Francisco   75000

# %%
import numpy as np

data = [
    ['Name', 'Age', 'City', 'Salary'],
    ['Alice', 25, 'New York', 70000],
    ['Bob', np.nan, 'Los Angeles', 80000],
    ['Charlie', 35, np.nan, 120000],
    ['David', 40, 'Houston', 90000],
    ['Eve', 28, 'San Francisco', np.nan]
]

df = pd.DataFrame(data[1:], columns=data[0])
df
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob   NaN    Los Angeles   80000.0
# 2  Charlie  35.0            NaN  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       NaN

# %%
# 결측값이 있는 행 제거
df_cleaned = df.dropna()
print(df_cleaned)
# Out:
#     Name   Age      City   Salary
# 0  Alice  25.0  New York  70000.0
# 3  David  40.0   Houston  90000.0

# %%
# 결측값을 0으로 대체
df_filled = df.fillna(0)
print(df_filled)

# 결측값을 평균값으로 대체
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df)
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob   0.0    Los Angeles   80000.0
# 2  Charlie  35.0              0  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       0.0
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob  32.0    Los Angeles   80000.0
# 2  Charlie  35.0            NaN  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       NaN

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob  32.0    Los Angeles   80000.0
# 2  Charlie  35.0            NaN  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco       NaN

# %%
df['Salary'] = df['Salary'].fillna(df['Salary'].median())
df
# Out:
#       Name   Age           City    Salary
# 0    Alice  25.0       New York   70000.0
# 1      Bob  32.0    Los Angeles   80000.0
# 2  Charlie  35.0            NaN  120000.0
# 3    David  40.0        Houston   90000.0
# 4      Eve  28.0  San Francisco   85000.0

# %%
data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],
        'Age': [25, 30, 25, 40]}

df = pd.DataFrame(data)

# 중복값 확인
print(df.duplicated())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   30
# 3  David   40

# %%
data = {'Name': ['Alice', 'Bob', 'Alice', 'David'],
        'Age': [25, 40, 25, 30]}
df = pd.DataFrame(data)

df_sorted = df.sort_values(by='Age')
print(df_sorted)

df_sorted_desc = df.sort_values(by='Age', ascending=False)
print(df_sorted_desc)
# Out:
#     Name  Age
# 0  Alice   25
# 2  Alice   25
# 3  David   30
# 1    Bob   40
#     Name  Age
# 1    Bob   40
# 3  David   30
# 0  Alice   25
# 2  Alice   25

# %%
df_sorted_mul = df.sort_values(by=['Name', 'Age'], ascending=(True, False))
print(df_sorted_mul)
# Out:
#     Name  Age
# 0  Alice   25
# 2  Alice   25
# 1    Bob   40
# 3  David   30

# %%
df_sorted_index = df.sort_index()
print(df_sorted_index)
# Out:
#     Name  Age
# 0  Alice   25
# 1    Bob   40
# 2  Alice   25
# 3  David   30

# %%
df_filtered = df[df['Age'] >= 30]
print(df_filtered)
# Out:
#     Name  Age
# 1    Bob   40
# 3  David   30

# %%
df_filtered = df[(df['Age'] >= 30) & (df['Name'] == 'Bob')]
print(df_filtered)
# Out:
#   Name  Age
# 1  Bob   40

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Score': [85, 90, 78, 92]
}

df = pd.DataFrame(data)

# 각 점수에 10점을 더하는 함수 적용
df['AdjustedScore'] = df['Score'].apply(lambda x: x + 10)
print(df)
# Out:
#       Name  Score  AdjustedScore
# 0    Alice     85             95
# 1      Bob     90            100
# 2  Charlie     78             88
# 3    David     92            102

# %%
# 성별 데이터 변환 예시
gender_data = pd.Series(['Male', 'Female', 'Female', 'Male'])

# 성별을 숫자로 변환
gender_numeric = gender_data.map(lambda x: 0 if x == 'Male' else 1)
print(gender_numeric)
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# dtype: int64

# %%
# 두 개의 데이터프레임 생성
df1 = pd.DataFrame({'CustomerID': [1, 2, 3], 'Product': ['Laptop', 'Mouse', 'Keyboard']})
df2 = pd.DataFrame({'CustomerID': [2, 3, 4], 'Location': ['USA', 'Canada', 'Mexico']})

# CustomerID를 기준으로 두 DataFrame 결합 (inner join)
df_merged = pd.merge(df1, df2, on='CustomerID', how='inner')
print(df_merged)
# Out:
#    CustomerID   Product Location
# 0           2     Mouse      USA
# 1           3  Keyboard   Canada

# %%
# 두 개의 데이터프레임을 세로로 연결
df1 = pd.DataFrame({'A': ['A0', 'A1'], 'B': ['B0', 'B1']})
df2 = pd.DataFrame({'A': ['A2', 'A3'], 'B': ['B2', 'B3']})

df_concat = pd.concat([df1, df2], axis=0)
print(df_concat)
df_concat = pd.concat([df1, df2], axis=0, ignore_index=True)
print(df_concat)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
# 예시 데이터프레임 생성
df1 = pd.DataFrame({'A': ['A0', 'A1']}, index=['K0', 'K1'])
df2 = pd.DataFrame({'B': ['B0', 'B1']}, index=['K0', 'K1'])

# join을 이용해 인덱스를 기준으로 결합
df_join = df1.join(df2)
print(df_join)
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1

# %%
data = {'Date': ['2024-01-01', '2024-01-01', '2024-01-02'],
        'City': ['New York', 'Los Angeles', 'New York'],
        'Temperature': [55, 68, 52]}

df_weather = pd.DataFrame(data)

# pivot을 이용해 날짜별 도시 온도 정리
df_pivot = df_weather.pivot(index='Date', columns='City', values='Temperature')
print(df_pivot)
# Out:
# City        Los Angeles  New York
# Date
# 2024-01-01         68.0      55.0
# 2024-01-02          NaN      52.0

# %%
sales_data = {
    'Product': ['A', 'B', 'A', 'B'],
    'Sales': [100, 150, 200, 250],
    'Region': ['North', 'South', 'North', 'South']
}

df_sales = pd.DataFrame(sales_data)

# pivot_table을 이용해 지역별, 상품별 총 판매량 요약
df_pivot_table = df_sales.pivot_table(values='Sales', index='Region', columns='Product', aggfunc='sum')
print(df_pivot_table)
# Out:
# Product      A      B
# Region
# North    300.0    NaN
# South      NaN  400.0

# %%
df_wide = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Math': [85, 90, 88, 80],
    'English': [78, 85, 90, 100],
    'Sci': [50, 60, 55, 56]
})
print(df_wide)
# melt를 이용해 긴 형식으로 변환
df_melt = pd.melt(df_wide, id_vars=['ID'], value_vars=['Math', 'English', 'Sci'], var_name='Subject', value_name='Score')
print(df_melt)
# Out:
#    ID  Math  English  Sci
# 0   1    85       78   50
# 1   2    90       85   60
# 2   3    88       90   55
# 3   4    80      100   56
#     ID  Subject  Score
# 0    1     Math     85
# 1    2     Math     90
# 2    3     Math     88
# 3    4     Math     80
# 4    1  English     78
# 5    2  English     85
# 6    3  English     90
# 7    4  English    100
# 8    1      Sci     50
# 9    2      Sci     60
# 10   3      Sci     55
# 11   4      Sci     56

# %%
data = {
    'Department': ['HR', 'IT', 'HR', 'Finance', 'IT', 'Finance'],
    'Salary': [50000, 60000, 52000, 80000, 65000, 90000]
}
df = pd.DataFrame(data)

# 부서별로 평균 급여 계산
grouped = df.groupby('Department')['Salary'].mean()
print(grouped)
# Out:
# Department
# Finance    85000.0
# HR         51000.0
# IT         62500.0
# Name: Salary, dtype: float64

# %%
data = {
    'Department': ['HR', 'IT', 'HR', 'Finance', 'IT', 'Finance'],
    'Location': ['New York', 'New York', 'Chicago', 'Chicago', 'New York', 'Chicago'],
    'Salary': [50000, 60000, 52000, 80000, 65000, 90000]
}
df = pd.DataFrame(data)
df
# Out:
#   Department  Location  Salary
# 0         HR  New York   50000
# 1         IT  New York   60000
# 2         HR   Chicago   52000
# 3    Finance   Chicago   80000
# 4         IT  New York   65000
# 5    Finance   Chicago   90000

# %%
# 부서와 위치별로 평균 급여 계산
grouped = df.groupby(['Department', 'Location'])['Salary'].mean()
grouped
# Out:
# Department  Location
# Finance     Chicago     85000.0
# HR          Chicago     52000.0
#             New York    50000.0
# IT          New York    62500.0
# Name: Salary, dtype: float64

# %%
# 부서별로 총 급여, 평균 급여, 직원 수 계산
aggregated = df.groupby('Department').agg({
    'Salary': ['sum', 'mean', 'count']
})
aggregated
# Out:
#             Salary
#                sum     mean count
# Department
# Finance     170000  85000.0     2
# HR          102000  51000.0     2
# IT          125000  62500.0     2

# %%
# 여러 집계 함수 적용
df.groupby('Department')['Salary'].agg(['sum', 'mean', 'min', 'max'])
# Out:
#                sum     mean    min    max
# Department
# Finance     170000  85000.0  80000  90000
# HR          102000  51000.0  50000  52000
# IT          125000  62500.0  60000  65000

# %%
# 평균 급여가 60000 이상인 부서만 선택
filtered = df.groupby('Department').filter(lambda x: x['Salary'].mean() >= 60000)
filtered
# Out:
#   Department  Location  Salary
# 1         IT  New York   60000
# 3    Finance   Chicago   80000
# 4         IT  New York   65000
# 5    Finance   Chicago   90000

# %%
unstacked = df.groupby(['Department', 'Location'])['Salary'].mean().unstack()
unstacked
# Out:
# Location    Chicago  New York
# Department
# Finance     85000.0       NaN
# HR          52000.0   50000.0
# IT              NaN   62500.0

# %%
stacked = unstacked.stack()
stacked
# Out:
# Department  Location
# Finance     Chicago     85000.0
#             New York        NaN
# HR          Chicago     52000.0
#             New York    50000.0
# IT          Chicago         NaN
#             New York    62500.0
# dtype: float64

# %%
df_reset = df.groupby('Department')['Salary'].mean().reset_index()
df_reset
# Out:
#   Department   Salary
# 0    Finance  85000.0
# 1         HR  51000.0
# 2         IT  62500.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 예시 데이터
data = {'Month': ['Jan', 'Feb', 'Mar', 'Apr', 'May'],
        'Sales': [200, 300, 400, 500, 450]}
df = pd.DataFrame(data)

# 선 그래프 그리기
df.plot(x='Month', y='Sales', kind='line', title='Monthly Sales')
plt.show()

# %%
# 막대 그래프 그리기
df.plot(x='Month', y='Sales', kind='bar', title='Monthly Sales')
plt.show()

# %%
# 히스토그램 그리기
df['Sales'].plot(kind='hist', title='Sales Distribution')
plt.show()

# %%
# 날짜 데이터를 datetime 형식으로 변환
df['Date'] = pd.to_datetime(df['Month'] + ' 2026')
df
# Out:
# C:\Users\playdata2\AppData\Local\Temp\ipykernel_18096\2854610842.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Month'] + ' 2026')
#            Month  Sales       Date
# Date
# 2026-01-01   Jan    200 2026-01-01
# 2026-02-01   Feb    300 2026-02-01
# 2026-03-01   Mar    400 2026-03-01
# 2026-04-01   Apr    500 2026-04-01
# 2026-05-01   May    450 2026-05-01

# %%
# 월별 데이터를 날짜로 변환 후 집계 예시
df.set_index('Date', inplace=True)
monthly_sales = df.resample('ME').sum()  # 'M'은 월별 집계를 의미
monthly_sales
# Out:
#            Month  Sales
# Date
# 2026-01-31   Jan    200
# 2026-02-28   Feb    300
# 2026-03-31   Mar    400
# 2026-04-30   Apr    500
# 2026-05-31   May    450

# %%
# 시계열 데이터 시각화
monthly_sales.plot(title='Monthly Sales Over Time')
plt.show()

# %%
# 3개월 이동 평균 계산 및 시각화
df['RollingMean'] = df['Sales'].rolling(window=3).mean()
df[['Sales', 'RollingMean']].plot(title='Sales and 3-Month Rolling Average')
plt.show()
