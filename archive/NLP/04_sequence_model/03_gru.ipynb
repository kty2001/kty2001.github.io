# %% [markdown]
# # GRU
#
# 인공지능 차세대 톱스타, 한국인 조경현 교수
#
#
# <img src="https://d.pr/i/5xtgUb+" width="500"/>
#
#
# **GRU(Gated Recurrent Unit)**는 RNN의 변형 구조 중 하나로, **LSTM(Long Short-Term Memory)**와 유사하지만 구조가 더 간단하다. GRU는 **게이트 구조**를 사용해 RNN의 **기울기 소멸 문제**를 해결하면서도, 연산량을 줄이고 효율적으로 학습할 수 있도록 설계되었다.(문제에 따라 LSTM보다 더 나은 경우도 있다.)
#
#
# 1. **단순화된 구조**
#    - GRU는 LSTM에서 사용되는 **셀 상태(Cell State)**와 **은닉 상태(Hidden State)**를 하나로 통합하여 **은닉 상태(h)**만 유지한다.
#    - LSTM의 3가지 게이트(망각, 입력, 출력 게이트) 대신, GRU는 **업데이트 게이트(Update Gate)**와 **리셋 게이트(Reset Gate)**의 2가지 게이트만 사용한다.
#
# 2. **장단기 의존성 처리**
#    - GRU는 중요한 정보는 기억하고, 불필요한 정보는 잊는 과정을 통해 장기 의존성과 단기 의존성을 모두 처리할 수 있다.
#
# 3. **연산 효율성**
#    - 구조가 단순하기 때문에 LSTM보다 계산량이 적고, 학습 속도가 더 빠르다.
#
# **GRU의 게이트 구조**
#
# 1. **리셋 게이트 (Reset Gate)**
#    - 과거 정보를 **얼마나 잊을지** 결정한다.
#    - 이전 은닉 상태가 현재 입력에 얼마나 반영될지를 제어한다.
#    - 수식:
# $$
# r_t = \sigma(W_r \cdot [h_{t-1}, x_t] + b_r)
# $$
#
# 2. **은닉 상태 업데이트**
#    - 새로운 은닉 상태는 리셋 게이트를 적용한 이전 은닉 상태와 현재 입력 정보를 결합하여 생성된다.
#    - 수식:
# $$
# \tilde{h}_t = \tanh(W_h \cdot [r_t \cdot h_{t-1}, x_t] + b_h)
# $$
#
# 3. **업데이트 게이트 (Update Gate)**
#    - 정보의 **기억 여부**를 결정한다.
#    - 이전 시점의 정보와 현재 입력 정보를 결합하여 다음 은닉 상태에 어떤 정보를 전달할지 제어한다.
#    - 수식:
# $$
# z_t = \sigma(W_z \cdot [h_{t-1}, x_t] + b_z)
# $$
#
#
#
# 4. **최종 은닉 상태**
#    - 업데이트 게이트를 사용해 이전 은닉 상태와 새로운 은닉 상태를 조합하여 최종 은닉 상태를 계산한다.
#    - 수식:
# $$
# h_t = (1 - z_t) \cdot h_{t-1} + z_t \cdot \tilde{h}_t
# $$
#
# **GRU와 LSTM의 차이점**
#
# | **특징**            | **LSTM**                                          | **GRU**                                  |
# |----------------------|--------------------------------------------------|------------------------------------------|
# | **게이트 수**        | 3개 (입력, 망각, 출력 게이트)                    | 2개 (업데이트 게이트, 리셋 게이트)              |
# | **상태**            | 셀 상태(Cell State), 은닉 상태(Hidden State)      | 은닉 상태(Hidden State)만 사용           |
# | **구조의 복잡성**   | 복잡함                                           | 단순함                                   |
# | **계산량**          | 상대적으로 많음                                  | 상대적으로 적음                          |
# | **성능 차이**        | 복잡한 시퀀스 데이터에 강점                      | 빠르고 간단한 시퀀스 데이터에 적합        |

# %%
# RNN 입력 / 출력 텐서 shape 확인
import torch
import torch.nn as nn

batch_size = 2    # B (배치) : 한 번에 처리할 샘플수
seq_len = 3       # T (타임스텝) : 시퀀스 길이
input_size = 4    # F (입력 차원) : vocab_size 또는 임베딩 차원
hidden_size = 5   # H : GRU 은닉 상태 차원

x = torch.randn(batch_size, seq_len, input_size)  # 입력 시퀀스 (B, T, F)
print(x.shape)

# GRU 생성 (B, T, F 형태 입력)
gru = nn.GRU(input_size, hidden_size, batch_first=True)

output, hidden = gru(x)  # 순전파 후 (전체 시점 출력, 마지막 은닉)
print(output.shape)  # (B, T, H) : 모든 시점의 은닉 출력들이 쌓인 결과
print(hidden.shape)  # (num_layers, B, H)  # 마지막 시점 은닉 상태(레이어별)
# Out:
# torch.Size([2, 3, 4])
# torch.Size([2, 3, 5])
# torch.Size([1, 2, 5])

# %%
from tensorflow.keras.datasets import imdb

vocab_size = 300  # 사용할 단어사전 크기 (상위 300개)

# IMDB 데이터 로드 (단어 ID 시퀀스)
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words = vocab_size)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (25000,) (25000,)
# (25000,) (25000,)

# %%
word_index = imdb.get_word_index()

# index_word 생성
index_from = 3
index_word = {index + index_from: word for word, index in word_index.items() if index <= vocab_size}
index_word[0] = '[PAD]'
index_word[1] = '[START]'
index_word[2] = '[UNK]'
index_word = dict(sorted(index_word.items(), key=lambda x: x[0]))
index_word
# Out:
# {0: '[PAD]',
#  1: '[START]',
#  2: '[UNK]',
#  4: 'the',
#  5: 'and',
#  6: 'a',
#  7: 'of',
#  8: 'to',
#  9: 'is',
#  10: 'br',
#  11: 'in',
#  12: 'it',
#  13: 'i',
#  14: 'this',
#  15: 'that',
#  16: 'was',
#  17: 'as',
#  18: 'for',
#  19: 'with',
#  20: 'movie',
#  21: 'but',
#  22: 'film',
#  23: 'on',
#  24: 'not',
#  25: 'you',
#  26: 'are',
#  27: 'his',
#  28: 'have',
#  29: 'he',
#  30: 'be',
#  31: 'one',
#  32: 'all',
#  33: 'at',
#  34: 'by',
#  35: 'an',
#  36: 'they',
#  37: 'who',
#  38: 'so',
#  39: 'from',
#  40: 'like',
#  41: 'her',
#  42: 'or',
#  43: 'just',
#  44: 'about',
#  45: "it's",
#  46: 'out',
#  47: 'has',
#  48: 'if',
#  49: 'some',
#  50: 'there',
#  51: 'what',
#  52: 'good',
#  53: 'more',
#  54: 'when',
#  55: 'very',
#  56: 'up',
#  57: 'no',
#  58: 'time',
#  59: 'she',
#  60: 'even',
#  61: 'my',
#  62: 'would',
#  63: 'which',
#  64: 'only',
#  65: 'story',
#  66: 'really',
#  67: 'see',
#  68: 'their',
#  69: 'had',
#  70: 'can',
#  71: 'were',
#  72: 'me',
#  73: 'well',
#  74: 'than',
#  75: 'we',
#  76: 'much',
#  77: 'been',
#  78: 'bad',
#  79: 'get',
#  80: 'will',
#  81: 'do',
#  82: 'also',
#  83: 'into',
#  84: 'people',
#  85: 'other',
#  86: 'first',
#  87: 'great',
#  88: 'because',
#  89: 'how',
#  90: 'him',
#  91: 'most',
#  92: "don't",
#  93: 'made',
#  94: 'its',
#  95: 'then',
#  96: 'way',
#  97: 'make',
#  98: 'them',
#  99: 'too',
#  100: 'could',
#  101: 'any',
#  102: 'movies',
#  103: 'after',
#  104: 'think',
#  105: 'characters',
#  106: 'watch',
#  107: 'two',
#  108: 'films',
#  109: 'character',
#  110: 'seen',
#  111: 'many',
#  112: 'being',
#  113: 'life',
#  114: 'plot',
#  115: 'never',
#  116: 'acting',
#  117: 'little',
#  118: 'best',
#  119: 'love',
#  120: 'over',
#  121: 'where',
#  122: 'did',
#  123: 'show',
#  124: 'know',
#  125: 'off',
#  126: 'ever',
#  127: 'does',
#  128: 'better',
#  129: 'your',
#  130: 'end',
#  131: 'still',
#  132: 'man',
#  133: 'here',
#  134: 'these',
#  135: 'say',
#  136: 'scene',
#  137: 'while',
#  138: 'why',
#  139: 'scenes',
#  140: 'go',
#  141: 'such',
#  142: 'something',
#  143: 'through',
#  144: 'should',
#  145: 'back',
#  146: "i'm",
#  147: 'real',
#  148: 'those',
#  149: 'watching',
#  150: 'now',
#  151: 'though',
#  152: "doesn't",
#  153: 'years',
#  154: 'old',
#  155: 'thing',
#  156: 'actors',
#  157: 'work',
#  158: '10',
#  159: 'before',
#  160: 'another',
#  161: "didn't",
#  162: 'new',
#  163: 'funny',
#  164: 'nothing',
#  165: 'actually',
#  166: 'makes',
#  167: 'director',
#  168: 'look',
#  169: 'find',
#  170: 'going',
#  171: 'few',
#  172: 'same',
#  173: 'part',
#  174: 'again',
#  175: 'every',
#  176: 'lot',
#  177: 'cast',
#  178: 'us',
#  179: 'quite',
#  180: 'down',
#  181: 'want',
#  182: 'world',
#  183: 'things',
#  184: 'pretty',
#  185: 'young',
#  186: 'seems',
#  187: 'around',
#  188: 'got',
#  189: 'horror',
#  190: 'however',
#  191: "can't",
#  192: 'fact',
#  193: 'take',
#  194: 'big',
#  195: 'enough',
#  196: 'long',
#  197: 'thought',
#  198: "that's",
#  199: 'both',
#  200: 'between',
#  201: 'series',
#  202: 'give',
#  203: 'may',
#  204: 'original',
#  205: 'own',
#  206: 'action',
#  207: "i've",
#  208: 'right',
#  209: 'without',
#  210: 'always',
#  211: 'times',
#  212: 'comedy',
#  213: 'point',
#  214: 'gets',
#  215: 'must',
#  216: 'come',
#  217: 'role',
#  218: "isn't",
#  219: 'saw',
#  220: 'almost',
#  221: 'interesting',
#  222: 'least',
#  223: 'family',
#  224: 'done',
#  225: "there's",
#  226: 'whole',
#  227: 'bit',
#  228: 'music',
#  229: 'script',
#  230: 'far',
#  231: 'making',
#  232: 'guy',
#  233: 'anything',
#  234: 'minutes',
#  235: 'feel',
#  236: 'last',
#  237: 'since',
#  238: 'might',
#  239: 'performance',
#  240: "he's",
#  241: '2',
#  242: 'probably',
#  243: 'kind',
#  244: 'am',
#  245: 'away',
#  246: 'yet',
#  247: 'rather',
#  248: 'tv',
#  249: 'worst',
#  250: 'girl',
#  251: 'day',
#  252: 'sure',
#  253: 'fun',
#  254: 'hard',
#  255: 'woman',
#  256: 'played',
#  257: 'each',
#  258: 'found',
#  259: 'anyone',
#  260: 'having',
#  261: 'although',
#  262: 'especially',
#  263: 'our',
#  264: 'believe',
#  265: 'course',
#  266: 'comes',
#  267: 'looking',
#  268: 'screen',
#  269: 'trying',
#  270: 'set',
#  271: 'goes',
#  272: 'looks',
#  273: 'place',
#  274: 'book',
#  275: 'different',
#  276: 'put',
#  277: 'ending',
#  278: 'money',
#  279: 'maybe',
#  280: 'once',
#  281: 'sense',
#  282: 'reason',
#  283: 'true',
#  284: 'actor',
#  285: 'everything',
#  286: "wasn't",
#  287: 'shows',
#  288: 'dvd',
#  289: 'three',
#  290: 'worth',
#  291: 'year',
#  292: 'job',
#  293: 'main',
#  294: 'someone',
#  295: 'together',
#  296: 'watched',
#  297: 'play',
#  298: 'american',
#  299: 'plays',
#  300: '1',
#  301: 'said',
#  302: 'effects',
#  303: 'later'}

# %%
print(X_train[0])
decoded = ' '.join([index_word.get(seq, '?') for seq in X_train[0]])
decoded
# Out:
# [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 2, 112, 50, 2, 2, 9, 35, 2, 284, 5, 150, 4, 172, 112, 167, 2, 2, 2, 39, 4, 172, 2, 2, 17, 2, 38, 13, 2, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 106, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 130, 12, 16, 38, 2, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 104, 88, 4, 2, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 2, 26, 2, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]
# "[START] this film was just [UNK] [UNK] [UNK] [UNK] story [UNK] [UNK] really [UNK] the part they played and you could just [UNK] being there [UNK] [UNK] is an [UNK] actor and now the same being director [UNK] [UNK] [UNK] from the same [UNK] [UNK] as [UNK] so i [UNK] the fact there was a real [UNK] with this film the [UNK] [UNK] [UNK] the film were great it was just [UNK] so much that i [UNK] the film as [UNK] as it was [UNK] for [UNK] and would [UNK] it to [UNK] to watch and the [UNK] [UNK] was [UNK] really [UNK] at the end it was so [UNK] and you know what they say if you [UNK] at a film it must have been good and this [UNK] was also [UNK] to the two little [UNK] that played the [UNK] of [UNK] and [UNK] they were just [UNK] [UNK] are [UNK] [UNK] out of the [UNK] [UNK] i think because the [UNK] that play them all [UNK] up are such a big [UNK] for the whole film but these [UNK] are [UNK] and should be [UNK] for what they have done don't you think the whole story was so [UNK] because it was true and was [UNK] life after all that was [UNK] with us all"

# %%
train_size = 15000
test_size = 10000

X_train = X_train[:train_size]
y_train = y_train[:train_size]

X_test = X_test[:test_size]
y_test = y_test[:test_size]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (15000,) (15000,)
# (10000,) (10000,)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

X_train = [torch.tensor(seq, dtype=torch.long) for seq in X_train]
X_test = [torch.tensor(seq, dtype=torch.long) for seq in X_test]
y_train = torch.tensor(y_train, dtype=torch.float).unsqueeze(1)
y_test = torch.tensor(y_test, dtype=torch.float).unsqueeze(1)

# %%
import torch.nn.functional as F

seq_len = 100

def pad_sequences(sequences, maxlen):
    padded_squences = []

    for seq in sequences:
        if len(seq) < maxlen:
            padded_seq = F.pad(seq, (0, maxlen - len(seq)), value=0)
        else:
            padded_seq = seq[:maxlen]
        padded_squences.append(padded_seq)
    return torch.stack(padded_squences)

X_train_padded = pad_sequences(X_train, seq_len)
X_test_padded = pad_sequences(X_test, seq_len)

X_train_padded.shape, X_test_padded.shape
# Out:
# (torch.Size([15000, 100]), torch.Size([10000, 100]))

# %%
class GRUSentimentNet(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)

    def forward(self, x):
        x = self.embedding(x)
        output, hidden = self.gru(x)
        output = self.fc(hidden[-1])
        return output

model = GRUSentimentNet(vocab_size, embedding_dim=100, hidden_dim=16)
model
# Out:
# GRUSentimentNet(
#   (embedding): Embedding(300, 100, padding_idx=0)
#   (gru): GRU(100, 16, batch_first=True)
#   (fc): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# embedding.weight torch.Size([300, 100])
# gru.weight_ih_l0 torch.Size([48, 100])
# gru.weight_hh_l0 torch.Size([48, 16])
# gru.bias_ih_l0 torch.Size([48])
# gru.bias_hh_l0 torch.Size([48])
# fc.weight torch.Size([1, 16])
# fc.bias torch.Size([1])

# %%
from torchinfo import summary
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# GRUSentimentNet                          --
# ├─Embedding: 1-1                         30,000
# ├─GRU: 1-2                               5,664
# ├─Linear: 1-3                            17
# =================================================================
# Total params: 35,681
# Trainable params: 35,681
# Non-trainable params: 0
# =================================================================

# %%
class GRUSentimentNet(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=0)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, 1)

    def forward(self, x):
        x = self.embedding(x)
        output, hidden = self.gru(x)

        forward_pass = hidden[-2]
        backward_pass = hidden[-1]
        hidden_merged = torch.cat((forward_pass, backward_pass), dim=1)

        output = self.fc(hidden_merged)
        return output

model = GRUSentimentNet(vocab_size, embedding_dim=100, hidden_dim=16)
model
# Out:
# GRUSentimentNet(
#   (embedding): Embedding(300, 100, padding_idx=0)
#   (gru): GRU(100, 16, batch_first=True, bidirectional=True)
#   (fc): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# embedding.weight torch.Size([300, 100])
# gru.weight_ih_l0 torch.Size([48, 100])
# gru.weight_hh_l0 torch.Size([48, 16])
# gru.bias_ih_l0 torch.Size([48])
# gru.bias_hh_l0 torch.Size([48])
# gru.weight_ih_l0_reverse torch.Size([48, 100])
# gru.weight_hh_l0_reverse torch.Size([48, 16])
# gru.bias_ih_l0_reverse torch.Size([48])
# gru.bias_hh_l0_reverse torch.Size([48])
# fc.weight torch.Size([1, 32])
# fc.bias torch.Size([1])

# %%
from torchinfo import summary
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# GRUSentimentNet                          --
# ├─Embedding: 1-1                         30,000
# ├─GRU: 1-2                               11,328
# ├─Linear: 1-3                            33
# =================================================================
# Total params: 41,361
# Trainable params: 41,361
# Non-trainable params: 0
# =================================================================

# %%
from torch.utils.data import random_split, DataLoader, TensorDataset

batch_size = 64
train_size = int(len(X_train_padded) * 0.8)
val_size = len(X_train_padded) - train_size

train_dataset, val_dataset = random_split(
    TensorDataset(X_train_padded, y_train), [train_size, val_size]
)
test_dataset = TensorDataset(X_test_padded, y_test)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device: {device}')

torch.cuda.empty_cache()

model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.0001)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer,
    mode='min',
    factor=0.5,
    patience=3
)

epochs = 100

trian_losses, val_losses, train_accs, val_accs = [], [], [], []

early_stopping_patience = 5
best_val_loss = float('inf')
early_stopping_counter = 0
# Out:
# device: cpu

# %%
from tqdm.auto import tqdm

for epoch in tqdm(range(epochs)):
    total_loss, correct, total = 0, 0, 0

    model.train()
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device).float()

        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        p = torch.sigmoid(output)
        pred = (p >= 0.5).float()
        correct += (pred == labels).sum().item()
        total += labels.size(0)

    train_loss = total_loss / len(train_dataloader)
    trian_losses.append(train_loss)
    train_acc = correct / total
    train_accs.append(train_acc)

    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for val_inputs, val_labels in val_dataloader:
            val_inputs = val_inputs.to(device)
            val_labels = val_labels.to(device).float()

            output = model(val_inputs)
            loss = criterion(output, val_labels)

            val_loss += loss.item()
            p = torch.sigmoid(output)
            pred = (p >= 0.5).float()
            val_correct += (pred == val_labels).sum().item()
            val_total += val_labels.size(0)

    val_loss = val_loss / len(val_dataloader)
    val_losses.append(val_loss)
    val_acc = val_correct / val_total
    val_accs.append(val_acc)

    scheduler.step(val_loss)
    lr = scheduler.get_last_lr()[0]

    print(f'Epoch {epoch+1}/{epochs}\n',
          f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}',
          f'Valid Loss: {val_loss:.4f}, Valid Acc: {val_acc:.4f}',
          f'lr: {lr}'
        )

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early Stopping on{epoch+1} Epoch')
            break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100
#  Train Loss: 0.6976, Train Acc: 0.5050 Valid Loss: 0.7000, Valid Acc: 0.4977 lr: 0.0001
# Epoch 2/100
#  Train Loss: 0.6936, Train Acc: 0.5228 Valid Loss: 0.6984, Valid Acc: 0.4980 lr: 0.0001
# Epoch 3/100
#  Train Loss: 0.6908, Train Acc: 0.5261 Valid Loss: 0.6948, Valid Acc: 0.5163 lr: 0.0001
# Epoch 4/100
#  Train Loss: 0.6882, Train Acc: 0.5410 Valid Loss: 0.6926, Valid Acc: 0.5233 lr: 0.0001
# Epoch 5/100
#  Train Loss: 0.6860, Train Acc: 0.5482 Valid Loss: 0.6916, Valid Acc: 0.5197 lr: 0.0001
# Epoch 6/100
#  Train Loss: 0.6836, Train Acc: 0.5543 Valid Loss: 0.6893, Valid Acc: 0.5287 lr: 0.0001
# Epoch 7/100
#  Train Loss: 0.6813, Train Acc: 0.5643 Valid Loss: 0.6885, Valid Acc: 0.5333 lr: 0.0001
# Epoch 8/100
#  Train Loss: 0.6793, Train Acc: 0.5702 Valid Loss: 0.6864, Valid Acc: 0.5380 lr: 0.0001
# Epoch 9/100
#  Train Loss: 0.6770, Train Acc: 0.5769 Valid Loss: 0.6848, Valid Acc: 0.5397 lr: 0.0001
# Epoch 10/100
#  Train Loss: 0.6747, Train Acc: 0.5826 Valid Loss: 0.6831, Valid Acc: 0.5473 lr: 0.0001
# Epoch 11/100
#  Train Loss: 0.6724, Train Acc: 0.5892 Valid Loss: 0.6817, Valid Acc: 0.5480 lr: 0.0001
# Epoch 12/100
#  Train Loss: 0.6700, Train Acc: 0.5930 Valid Loss: 0.6809, Valid Acc: 0.5493 lr: 0.0001
# Epoch 13/100
#  Train Loss: 0.6677, Train Acc: 0.5973 Valid Loss: 0.6795, Valid Acc: 0.5490 lr: 0.0001
# Epoch 14/100
#  Train Loss: 0.6646, Train Acc: 0.6013 Valid Loss: 0.6766, Valid Acc: 0.5677 lr: 0.0001
# Epoch 15/100
#  Train Loss: 0.6615, Train Acc: 0.6083 Valid Loss: 0.6749, Valid Acc: 0.5680 lr: 0.0001
# Epoch 16/100
#  Train Loss: 0.6579, Train Acc: 0.6152 Valid Loss: 0.6719, Valid Acc: 0.5793 lr: 0.0001
# Epoch 17/100
#  Train Loss: 0.6539, Train Acc: 0.6231 Valid Loss: 0.6698, Valid Acc: 0.5840 lr: 0.0001
# Epoch 18/100
#  Train Loss: 0.6490, Train Acc: 0.6304 Valid Loss: 0.6666, Valid Acc: 0.5960 lr: 0.0001
# Epoch 19/100
#  Train Loss: 0.6435, Train Acc: 0.6383 Valid Loss: 0.6631, Valid Acc: 0.6010 lr: 0.0001
# Epoch 20/100
#  Train Loss: 0.6374, Train Acc: 0.6428 Valid Loss: 0.6603, Valid Acc: 0.6043 lr: 0.0001
# Epoch 21/100
#  Train Loss: 0.6306, Train Acc: 0.6490 Valid Loss: 0.6568, Valid Acc: 0.6120 lr: 0.0001
# Epoch 22/100
#  Train Loss: 0.6231, Train Acc: 0.6543 Valid Loss: 0.6526, Valid Acc: 0.6203 lr: 0.0001
# Epoch 23/100
#  Train Loss: 0.6155, Train Acc: 0.6621 Valid Loss: 0.6481, Valid Acc: 0.6253 lr: 0.0001
# Epoch 24/100
#  Train Loss: 0.6078, Train Acc: 0.6695 Valid Loss: 0.6450, Valid Acc: 0.6240 lr: 0.0001
# Epoch 25/100
#  Train Loss: 0.5997, Train Acc: 0.6770 Valid Loss: 0.6426, Valid Acc: 0.6280 lr: 0.0001
# Epoch 26/100
#  Train Loss: 0.5919, Train Acc: 0.6844 Valid Loss: 0.6406, Valid Acc: 0.6290 lr: 0.0001
# Epoch 27/100
#  Train Loss: 0.5842, Train Acc: 0.6913 Valid Loss: 0.6382, Valid Acc: 0.6327 lr: 0.0001
# Epoch 28/100
#  Train Loss: 0.5769, Train Acc: 0.6995 Valid Loss: 0.6318, Valid Acc: 0.6417 lr: 0.0001
# Epoch 29/100
#  Train Loss: 0.5700, Train Acc: 0.7037 Valid Loss: 0.6320, Valid Acc: 0.6450 lr: 0.0001
# Epoch 30/100
#  Train Loss: 0.5637, Train Acc: 0.7105 Valid Loss: 0.6258, Valid Acc: 0.6533 lr: 0.0001
# Epoch 31/100
#  Train Loss: 0.5577, Train Acc: 0.7164 Valid Loss: 0.6234, Valid Acc: 0.6573 lr: 0.0001
# Epoch 32/100
#  Train Loss: 0.5517, Train Acc: 0.7205 Valid Loss: 0.6217, Valid Acc: 0.6607 lr: 0.0001
# Epoch 33/100
#  Train Loss: 0.5460, Train Acc: 0.7246 Valid Loss: 0.6184, Valid Acc: 0.6607 lr: 0.0001
# Epoch 34/100
#  Train Loss: 0.5407, Train Acc: 0.7322 Valid Loss: 0.6169, Valid Acc: 0.6677 lr: 0.0001
# Epoch 35/100
#  Train Loss: 0.5356, Train Acc: 0.7361 Valid Loss: 0.6160, Valid Acc: 0.6710 lr: 0.0001
# Epoch 36/100
#  Train Loss: 0.5309, Train Acc: 0.7384 Valid Loss: 0.6123, Valid Acc: 0.6707 lr: 0.0001
# Epoch 37/100
#  Train Loss: 0.5268, Train Acc: 0.7421 Valid Loss: 0.6118, Valid Acc: 0.6727 lr: 0.0001
# Epoch 38/100
#  Train Loss: 0.5219, Train Acc: 0.7462 Valid Loss: 0.6091, Valid Acc: 0.6727 lr: 0.0001
# Epoch 39/100
#  Train Loss: 0.5183, Train Acc: 0.7470 Valid Loss: 0.6084, Valid Acc: 0.6750 lr: 0.0001
# Epoch 40/100
#  Train Loss: 0.5139, Train Acc: 0.7518 Valid Loss: 0.6107, Valid Acc: 0.6850 lr: 0.0001
# Epoch 41/100
#  Train Loss: 0.5110, Train Acc: 0.7501 Valid Loss: 0.6074, Valid Acc: 0.6860 lr: 0.0001
# Epoch 42/100
#  Train Loss: 0.5066, Train Acc: 0.7572 Valid Loss: 0.6045, Valid Acc: 0.6803 lr: 0.0001
# Epoch 43/100
#  Train Loss: 0.5034, Train Acc: 0.7568 Valid Loss: 0.6050, Valid Acc: 0.6867 lr: 0.0001
# Epoch 44/100
#  Train Loss: 0.5006, Train Acc: 0.7595 Valid Loss: 0.6042, Valid Acc: 0.6850 lr: 0.0001
# Epoch 45/100
#  Train Loss: 0.4968, Train Acc: 0.7642 Valid Loss: 0.6035, Valid Acc: 0.6863 lr: 0.0001
# Epoch 46/100
#  Train Loss: 0.4937, Train Acc: 0.7688 Valid Loss: 0.6045, Valid Acc: 0.6890 lr: 0.0001
# Epoch 47/100
#  Train Loss: 0.4904, Train Acc: 0.7681 Valid Loss: 0.6043, Valid Acc: 0.6940 lr: 0.0001
# Epoch 48/100
#  Train Loss: 0.4876, Train Acc: 0.7708 Valid Loss: 0.6021, Valid Acc: 0.6880 lr: 0.0001
# Epoch 49/100
#  Train Loss: 0.4848, Train Acc: 0.7716 Valid Loss: 0.6009, Valid Acc: 0.6907 lr: 0.0001
# Epoch 50/100
#  Train Loss: 0.4822, Train Acc: 0.7735 Valid Loss: 0.6026, Valid Acc: 0.6920 lr: 0.0001
# Epoch 51/100
#  Train Loss: 0.4802, Train Acc: 0.7743 Valid Loss: 0.6001, Valid Acc: 0.6920 lr: 0.0001
# Epoch 52/100
#  Train Loss: 0.4778, Train Acc: 0.7767 Valid Loss: 0.6007, Valid Acc: 0.6947 lr: 0.0001
# Epoch 53/100
#  Train Loss: 0.4738, Train Acc: 0.7768 Valid Loss: 0.6010, Valid Acc: 0.6963 lr: 0.0001
# Epoch 54/100
#  Train Loss: 0.4723, Train Acc: 0.7797 Valid Loss: 0.6008, Valid Acc: 0.6963 lr: 0.0001
# Epoch 55/100
#  Train Loss: 0.4691, Train Acc: 0.7822 Valid Loss: 0.6007, Valid Acc: 0.6977 lr: 5e-05
# Epoch 56/100
#  Train Loss: 0.4659, Train Acc: 0.7827 Valid Loss: 0.6036, Valid Acc: 0.6967 lr: 5e-05
# Early Stopping on56 Epoch

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'train_loss': trian_losses,
    'val_loss': val_losses,
    'train_acc': train_accs,
    'val_accs': val_accs
})

df.plot()
plt.show()

# %%
def evaluate_model(model, test_dataloader, criterion, device):
    model.to(device).eval()
    test_loss, test_correct, test_total = 0, 0, 0
    with torch.no_grad():
        for test_inputs, test_labels in test_dataloader:
            test_inputs = test_inputs.to(device)
            test_labels = test_labels.to(device).float()

            output = model(test_inputs)
            loss = criterion(output, test_labels)

            test_loss += loss.item()
            p = torch.sigmoid(output)
            pred = (p >= 0.5).float()
            test_correct += (pred == test_labels).sum().item()
            test_total += test_labels.size(0)

        test_loss = test_loss / len(test_dataloader)
        test_acc = test_correct / test_total
    return test_loss, test_acc

test_dataset = TensorDataset(X_test_padded, y_test)
test_dataloader = DataLoader(test_dataset, batch_size, shuffle=False)

test_loss, test_acc = evaluate_model(model, test_dataloader, criterion, device)
print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Test Loss: 0.5856, Test Acc: 0.7055
