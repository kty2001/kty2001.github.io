# %% [markdown]
# # Sequential Data
# Sequential Data(순차 데이터)는 데이터의 요소들이 특정한 순서로 정렬되어 있고, 이 순서가 데이터의 의미를 결정하는 데이터 유형이다.
#
# 시간, 순서, 위치 등 순차적인 흐름을 따르는 데이터를 포함한다. 일반적으로 자연어 처리, 시계열 분석, 음성 신호 처리, 주식 데이터, 센서 데이터 등 다양한 응용 분야에서 활용된다.
#
# **특징**
# 1. **순서의 중요성**
#    데이터의 순서가 결과를 결정짓는 데 중요한 역할을 한다. 예를 들어, 텍스트 데이터에서 단어의 순서가 문장의 의미를 결정한다.
#
# 2. **시점 정보 포함**
#    데이터가 특정 시점 또는 위치에서 발생한 정보일 경우, 시점 정보가 데이터의 해석에 중요하다.
#
# 3. **연속성**
#    데이터가 시간 축이나 공간 축에서 연속적으로 변화하며 상관관계를 가질 수 있다.
#
# **예시**
# - Speech recognition: 파동의 연속 → 단어의 연속으로 변환
# - Music generation : 연속된 음표 출력
# - Sentiment classification: Text → 평점, 부정/긍정 판단
# - DNA 분석 : 염기서열 → 질병유무, 단백질 종류 등 (chatGPT/생성 모델까지)
# - 자동 번역: 한국어 → 영어
# - Video activity recognition: 연속된 장면 → 행동 판단
# - Financial Data: 시계열자료 → 주가, 환율예측 등
#
# **분석 방법**
# 1. **통계적 분석**
#    - 이동 평균, 분산 분석 등을 통해 시간 또는 순서의 변화 패턴 파악
#
# 2. **머신러닝**
#    - Recurrent Neural Network(RNN), Long Short-Term Memory(LSTM), Gated Recurrent Unit(GRU) 등 순차 데이터 학습을 위한 신경망 사용
#
# 3. **트랜스포머 모델**
#    - 자연어 처리 및 시계열 분석에서 효율적으로 순차적 패턴을 학습
#
#
# # RNN
#
#
# RNN(Recurrent Neural Network)은 **순차 데이터(Sequential Data)**를 처리하기 위해 설계된 인공 신경망이다. RNN은 입력 데이터의 시간적 순서를 고려하여 정보를 처리하며, 특히 텍스트, 음성, 시계열 데이터 등에서 많이 사용된다.
#
#
# - **특화**: 시퀀스 데이터 처리에 강점이 있음
# - **기억 능력**: 이전 입력을 '기억'하며 처리
#   - 네트워크는 입력 데이터를 요약하여 기억을 저장
#   - 새로운 입력이 들어올 때마다 기억을 조금씩 수정
#   - 모든 입력을 처리한 후, 남은 기억은 시퀀스를 전체적으로 요약하는 정보로 활용
# - **반복적 처리**: 입력마다 기억을 갱신하며 순환적으로 진행 (사람이 단어를 기억하며 이해하는 방식과 유사)
#
#
#
# **RNN 다양한 입출력 타입**
#
# ![](https://d.pr/i/s2J7sK+)
#
# 1. **One-to-One**
#    - 입력 데이터 하나에 출력 데이터 하나를 생성하는 구조.
#    - 이미지 분류 (Image Classification)
#
# 2. **One-to-Many**
#    - 하나의 입력 데이터를 기반으로 다수의 출력 시퀀스를 생성.
#    -
#      - 이미지로부터 문장 생성 (Image Captioning)
#      - 작곡, 작시
#
# 3. **Many-to-One**
#    - 여러 입력 시퀀스를 받아 하나의 출력 데이터를 생성.
#    -
#      - 감정 분석 (Sentiment Analysis, 예: Positive/Negative)
#      - 스팸 탐지 (Spam Detection)
#
# 4. **Many-to-Many (동일 길이)**
#    - 입력과 출력 시퀀스의 길이가 동일한 구조.
#    -
#      - Video 각 frame에 label 생성
#      - 품사 태깅 (Part-of-Speech Tagging)
#      - 개체명 인식 (Named Entity Recognition)
#      - Character 단위 문장 생성
#
# 5. **Many-to-Many (다른 길이)**
#    - 입력과 출력 시퀀스의 길이가 다를 수 있는 구조.
#    -
#      - 기계 번역 (영어 → 한국어 문장)
#      - 챗봇 (Chatbot)
#      - 질문 응답 (Question Answering)
#
#
# **RNN 구조 (Unfolding)**
#
# ![](https://d.pr/i/w43PfD+)
#
# - RNN을 순서대로 펼쳐놓으면 weight을 공유하는 매우 깊은 신경망이 된다.
# - RNN의 오차역전파는 BPTT Backpropagation Through Time)으로 처리된다.
#
#
# 1. **은닉 상태 업데이트**
#    $
#    h_t = \tanh(W_h \cdot h_{t-1} + W_x \cdot x_t + b_h)
#    $
#    - $h_t$: 현재 시점의 은닉 상태
#    - $h_{t-1}$: 이전 시점의 은닉 상태
#    - $x_t$: 현재 입력 데이터
#    - $W_h, W_x, b_h$: 가중치 및 편향
#
# 2. **출력 계산**
#    $
#    y_t = W_y \cdot h_t + b_y
#    $
#    - $y_t$: 현재 시점의 출력
#    - $W_y, b_y$: 출력 가중치 및 편향
#
#
# **RNN의 동작 과정**
#
# 1. 첫 번째 시점 $t=1$:
#    - 입력 $x_1$를 받아 은닉 상태 $h_1$ 계산.
#    - 출력 $y_1$ 생성.
#
# 2. 두 번째 시점 $t=2$:
#    - 이전 은닉 상태 $h_1$와 현재 입력 $x_2$를 사용해 $h_2$ 계산.
#    - 출력 $y_2$ 생성.
#
# 3. 반복:
#    - 다음 시점 $t$에서도 동일한 과정을 반복.
#
# **RNN의 단점**
#
# 1. **기울기 소멸 및 폭발 문제**
#    - 역전파 과정에서 기울기가 매우 작아지거나 커져 학습이 어려워진다.
#    - 이 문제를 해결하기 위해 LSTM(Long Short-Term Memory)과 GRU(Gated Recurrent Unit) 같은 변형 구조가 개발되었다.
#
# 2. **장기 의존성 문제**
#    - 오래된 과거 정보가 현재 출력에 반영되지 못하는 문제가 발생한다.
#
#
#
# **RNN 구현체**
# 1. **RNN**: 단순 구조, 기울기 소멸 문제 발생.
# 2. **LSTM**: 게이트 구조 추가로 장기 의존성을 처리.
# 3. **GRU**: LSTM보다 간단한 구조로 비슷한 성능 제공.
#
#
# **RNN 학습과정**
#
# vocab은 `['h', 'e', 'l', 'o']`일때, one-hot encoding된 입력데이터를 제공하고, 입력에 적절한 출력이 나오는 모델을 훈련시키는 과정
# 1. h가 입력되면, e가 나와야 한다.
# 2. e가 제일 큰 예측치를 가지도록 Back Propagation이 일어난다. 이때는 time step을 거슬러 역전파를 수행하므로 이를 특별히 BPTT Back Propagation Through Time이라고 한다.
# 3. e가 입력되면, l이 나와야 하며, 첫번재 l이 입력되면, l이 나오고, 두번째 l이 입력되면, o가 나와야 한다.
# 4. 이게 가능한 이유는 e가 입력될때, 은닉상태로 h가 전달되고, 첫번재 l이 입력될때 은닉상태로 he가 전달되고, 두번째 l이 입력될때 hel이 전달되기 때문이다.
# 5. 다만 RNN의 단기 기억 특성상 직전 기억에 비해 이전 기억은 계속 소실되는 경향이 있다.
#
# ![](https://d.pr/i/dnmFIq+)
#
#
# ## RNN 구조

# %%
import torch
import torch.nn as nn

batch_size = 2
seq_len = 3
input_size = 4
hidden_size = 5

x = torch.randn(batch_size, seq_len, input_size)
print(x.shape)

rnn = nn.RNN(input_size, hidden_size, batch_first=True)
output, hidden = rnn(x)

print(output.shape)
print(hidden.shape)
# Out:
# torch.Size([2, 3, 4])
# torch.Size([2, 3, 5])
# torch.Size([1, 2, 5])

# %% [markdown]
# ## IMDB 리뷰 감성분석
# - IMDB 데이터는 영화 리뷰 텍스트와 그 리뷰의 감성(긍정/부정) 라벨로 구성된 이진 분류용 데이터셋
# - 입력(X): 영화 리뷰 문장(원문 텍스트) → `tensorflow.keras.datasets.imdb`로 불러오면 “바로 모델에 넣어 실습할 수 있게” 미리 전처리된 형태(단어→정수 ID)로 제공
# - 정답(y): 감성 라벨 0=부정, 1=긍정
# - imdb.load_data(num_words=vocab_size)의 의미: 빈도 상위 vocab_size개 단어만 단어사전에 남기고, 나머지는(덜 나온 단어) 잘리거나 OOV로 처리되는 방식
#
# - 결과적으로 **“영화 리뷰가 긍정인지 부정인지 맞추는 감성분류 데이터”**

# %%
from tensorflow.keras.datasets import imdb

vocab_size = 300

(X_train, y_train), (X_test,  y_test) = imdb.load_data(num_words=vocab_size)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (25000,) (25000,)
# (25000,) (25000,)

# %%
print(X_train[0])
# Out:
# [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 2, 112, 50, 2, 2, 9, 35, 2, 284, 5, 150, 4, 172, 112, 167, 2, 2, 2, 39, 4, 172, 2, 2, 17, 2, 38, 13, 2, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 106, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 130, 12, 16, 38, 2, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 104, 88, 4, 2, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 2, 26, 2, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]

# %%
print(y_train[0])
# Out:
# 1

# %%
X_test = X_test[:10000]
y_test = y_test[:10000]
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (25000,) (25000,)
# (10000,) (10000,)

# %%
print(type(X_train), X_train.shape)
print(len(X_train[0]), X_train[0])
print(len(X_train[1]), X_train[1])
# Out:
# <class 'numpy.ndarray'> (25000,)
# 218 [1, 14, 22, 16, 43, 2, 2, 2, 2, 65, 2, 2, 66, 2, 4, 173, 36, 256, 5, 25, 100, 43, 2, 112, 50, 2, 2, 9, 35, 2, 284, 5, 150, 4, 172, 112, 167, 2, 2, 2, 39, 4, 172, 2, 2, 17, 2, 38, 13, 2, 4, 192, 50, 16, 6, 147, 2, 19, 14, 22, 4, 2, 2, 2, 4, 22, 71, 87, 12, 16, 43, 2, 38, 76, 15, 13, 2, 4, 22, 17, 2, 17, 12, 16, 2, 18, 2, 5, 62, 2, 12, 8, 2, 8, 106, 5, 4, 2, 2, 16, 2, 66, 2, 33, 4, 130, 12, 16, 38, 2, 5, 25, 124, 51, 36, 135, 48, 25, 2, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 2, 16, 82, 2, 8, 4, 107, 117, 2, 15, 256, 4, 2, 7, 2, 5, 2, 36, 71, 43, 2, 2, 26, 2, 2, 46, 7, 4, 2, 2, 13, 104, 88, 4, 2, 15, 297, 98, 32, 2, 56, 26, 141, 6, 194, 2, 18, 4, 226, 22, 21, 134, 2, 26, 2, 5, 144, 30, 2, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 2, 88, 12, 16, 283, 5, 16, 2, 113, 103, 32, 15, 16, 2, 19, 178, 32]
# 189 [1, 194, 2, 194, 2, 78, 228, 5, 6, 2, 2, 2, 134, 26, 4, 2, 8, 118, 2, 14, 2, 20, 13, 119, 2, 189, 102, 5, 207, 110, 2, 21, 14, 69, 188, 8, 30, 23, 7, 4, 249, 126, 93, 4, 114, 9, 2, 2, 5, 2, 4, 116, 9, 35, 2, 4, 229, 9, 2, 2, 4, 118, 9, 4, 130, 2, 19, 4, 2, 5, 89, 29, 2, 46, 37, 4, 2, 9, 45, 43, 38, 2, 2, 2, 4, 2, 26, 2, 5, 163, 11, 2, 2, 4, 2, 9, 194, 2, 7, 2, 2, 2, 2, 148, 2, 2, 2, 15, 123, 125, 68, 2, 2, 15, 2, 165, 2, 98, 5, 4, 228, 9, 43, 2, 2, 15, 299, 120, 5, 120, 174, 11, 220, 175, 136, 50, 9, 2, 228, 2, 5, 2, 2, 245, 2, 5, 4, 2, 131, 152, 2, 18, 2, 32, 2, 2, 14, 9, 6, 2, 78, 22, 2, 64, 2, 9, 8, 168, 145, 23, 4, 2, 15, 16, 4, 2, 5, 28, 6, 52, 154, 2, 33, 89, 78, 285, 16, 145, 95]

# %%
import torch
import torch.nn as nn
import torch.optim as optim

X_train = [torch.tensor(seq, dtype=torch.long) for seq in X_train]
X_test = [torch.tensor(seq, dtype=torch.long) for seq in X_test]
y_train = torch.tensor(y_train, dtype=torch.float)
y_test = torch.tensor(y_test, dtype=torch.float)

# %%
import matplotlib.pyplot as plt
import numpy as np

X_train_len = [len(seq) for seq in X_train]
X_train_len_mean = np.mean(X_train_len)
X_train_len_median = np.median(X_train_len)
print(max(X_train_len))

plt.hist(X_train_len, bins=50)
plt.xlabel('Sequence Length')
plt.ylabel('Frequency')
plt.title(f'<Seq Len> mean: {X_train_len_mean}, <Seq Len> median: {X_train_len_median}')
plt.show()
# Out:
# 2494

# %%
import torch.nn.functional as F

seq_len = 100

def pad_sequences(sequences, maxlen):
    padded_squences = []

    for seq in sequences:
        if len(seq) < maxlen:
            padded_seq = F.pad(seq, (0, maxlen - len(seq)), value=0)
        else:
            padded_seq = seq[:maxlen]
        padded_squences.append(padded_seq)
    return torch.stack(padded_squences)

X_train_padded = pad_sequences(X_train, seq_len)
X_test_padded = pad_sequences(X_test, seq_len)

X_train_padded.shape, X_test_padded.shape
# Out:
# (torch.Size([25000, 100]), torch.Size([10000, 100]))

# %%
print(X_train[0])
print(X_train_padded[0])
# Out:
# tensor([  1,  14,  22,  16,  43,   2,   2,   2,   2,  65,   2,   2,  66,   2,
#           4, 173,  36, 256,   5,  25, 100,  43,   2, 112,  50,   2,   2,   9,
#          35,   2, 284,   5, 150,   4, 172, 112, 167,   2,   2,   2,  39,   4,
#         172,   2,   2,  17,   2,  38,  13,   2,   4, 192,  50,  16,   6, 147,
#           2,  19,  14,  22,   4,   2,   2,   2,   4,  22,  71,  87,  12,  16,
#          43,   2,  38,  76,  15,  13,   2,   4,  22,  17,   2,  17,  12,  16,
#           2,  18,   2,   5,  62,   2,  12,   8,   2,   8, 106,   5,   4,   2,
#           2,  16,   2,  66,   2,  33,   4, 130,  12,  16,  38,   2,   5,  25,
#         124,  51,  36, 135,  48,  25,   2,  33,   6,  22,  12, 215,  28,  77,
#          52,   5,  14,   2,  16,  82,   2,   8,   4, 107, 117,   2,  15, 256,
#           4,   2,   7,   2,   5,   2,  36,  71,  43,   2,   2,  26,   2,   2,
#          46,   7,   4,   2,   2,  13, 104,  88,   4,   2,  15, 297,  98,  32,
#           2,  56,  26, 141,   6, 194,   2,  18,   4, 226,  22,  21, 134,   2,
#          26,   2,   5, 144,  30,   2,  18,  51,  36,  28, 224,  92,  25, 104,
#           4, 226,  65,  16,  38,   2,  88,  12,  16, 283,   5,  16,   2, 113,
#         103,  32,  15,  16,   2,  19, 178,  32])
# tensor([  1,  14,  22,  16,  43,   2,   2,   2,   2,  65,   2,   2,  66,   2,
#           4, 173,  36, 256,   5,  25, 100,  43,   2, 112,  50,   2,   2,   9,
#          35,   2, 284,   5, 150,   4, 172, 112, 167,   2,   2,   2,  39,   4,
#         172,   2,   2,  17,   2,  38,  13,   2,   4, 192,  50,  16,   6, 147,
#           2,  19,  14,  22,   4,   2,   2,   2,   4,  22,  71,  87,  12,  16,
#          43,   2,  38,  76,  15,  13,   2,   4,  22,  17,   2,  17,  12,  16,
#           2,  18,   2,   5,  62,   2,  12,   8,   2,   8, 106,   5,   4,   2,
#           2,  16])

# %%
X_train_onehot = F.one_hot(X_train_padded, num_classes=vocab_size)
X_test_onehot = F.one_hot(X_test_padded, num_classes=vocab_size)

X_train_onehot.shape, X_test_onehot.shape
# Out:
# (torch.Size([25000, 100, 300]), torch.Size([10000, 100, 300]))

# %%
class IMDBSentimentRNN(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super().__init__()
        self.rnn = nn.RNN(
            input_size=input_dim,
            hidden_size=hidden_dim,
            batch_first=True
        )
        self.fc = nn.Linear(hidden_dim, output_dim)

    def forward(self, x):
        output, hidden = self.rnn(x)
        output = self.fc(hidden.squeeze(0))
        return output

input_dim = vocab_size
hidden_dim = 8
output_dim = 1

model = IMDBSentimentRNN(input_dim, hidden_dim, output_dim)
model
# Out:
# IMDBSentimentRNN(
#   (rnn): RNN(300, 8, batch_first=True)
#   (fc): Linear(in_features=8, out_features=1, bias=True)
# )

# %%
for name, param in model.named_parameters():
    print(name, param.shape)
# Out:
# rnn.weight_ih_l0 torch.Size([8, 300])
# rnn.weight_hh_l0 torch.Size([8, 8])
# rnn.bias_ih_l0 torch.Size([8])
# rnn.bias_hh_l0 torch.Size([8])
# fc.weight torch.Size([1, 8])
# fc.bias torch.Size([1])

# %%
from torchinfo import summary
summary(model)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# IMDBSentimentRNN                         --
# ├─RNN: 1-1                               2,480
# ├─Linear: 1-2                            9
# =================================================================
# Total params: 2,489
# Trainable params: 2,489
# Non-trainable params: 0
# =================================================================

# %%
y_train = y_train.unsqueeze(1)
y_test = y_test.unsqueeze(1)

y_train.shape, y_test.shape
# Out:
# (torch.Size([25000, 1]), torch.Size([10000, 1]))

# %%
from torch.utils.data import random_split, DataLoader, TensorDataset

batch_size = 64
train_size = int(len(X_train_onehot) * 0.8)
val_size = len(X_train_onehot) - train_size

train_dataset, val_dataset = random_split(
    TensorDataset(X_train_onehot, y_train), [train_size, val_size]
)

train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device: {device}')

torch.cuda.empty_cache()

model = model.to(device)

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr = 0.0001)

epochs = 100

trian_losses, val_losses, train_accs, val_accs = [], [], [], []

early_stopping_patience = 20
best_val_loss = float('inf')
early_stopping_counter = 0
# Out:
# device: cpu

# %%
from tqdm.auto import tqdm

for epoch in tqdm(range(epochs)):
    total_loss, correct, total = 0, 0, 0

    model.train()
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device).float()
        labels = labels.to(device).float()

        optimizer.zero_grad()
        output = model(inputs)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()
        p = torch.sigmoid(output)
        pred = (p >= 0.5).float()
        correct += (pred == labels).sum().item()
        total += labels.size(0)

    train_loss = total_loss / len(train_dataloader)
    trian_losses.append(train_loss)
    train_acc = correct / total
    train_accs.append(train_acc)

    model.eval()
    val_loss, val_correct, val_total = 0, 0, 0
    with torch.no_grad():
        for val_inputs, val_labels in val_dataloader:
            val_inputs = val_inputs.to(device).float()
            val_labels = val_labels.to(device).float()

            output = model(val_inputs)
            loss = criterion(output, val_labels)

            val_loss += loss.item()
            p = torch.sigmoid(output)
            pred = (p >= 0.5).float()
            val_correct += (pred == val_labels).sum().item()
            val_total += val_labels.size(0)

    val_loss = val_loss / len(val_dataloader)
    val_losses.append(val_loss)
    val_acc = val_correct / val_total
    val_accs.append(val_acc)

    print(f'Epoch {epoch+1}/{epochs}\n',
          f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc}',
          f'Valid Loss: {val_loss:.4f}, Valid Acc: {val_acc}')

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        early_stopping_counter = 0
    else:
        early_stopping_counter += 1
        if early_stopping_counter >= early_stopping_patience:
            print(f'Early Stopping on{epoch+1} Epoch')
            break
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch 1/100
#  Train Loss: 0.6945, Train Acc: 0.50945 Valid Loss: 0.6944, Valid Acc: 0.511
# Epoch 2/100
#  Train Loss: 0.6935, Train Acc: 0.51455 Valid Loss: 0.6939, Valid Acc: 0.5086
# Epoch 3/100
#  Train Loss: 0.6931, Train Acc: 0.5172 Valid Loss: 0.6936, Valid Acc: 0.5114
# Epoch 4/100
#  Train Loss: 0.6927, Train Acc: 0.5182 Valid Loss: 0.6934, Valid Acc: 0.5112
# Epoch 5/100
#  Train Loss: 0.6925, Train Acc: 0.5171 Valid Loss: 0.6933, Valid Acc: 0.5142
# Epoch 6/100
#  Train Loss: 0.6922, Train Acc: 0.51765 Valid Loss: 0.6933, Valid Acc: 0.514
# Epoch 7/100
#  Train Loss: 0.6920, Train Acc: 0.51935 Valid Loss: 0.6932, Valid Acc: 0.514
# Epoch 8/100
#  Train Loss: 0.6917, Train Acc: 0.52005 Valid Loss: 0.6931, Valid Acc: 0.5148
# Epoch 9/100
#  Train Loss: 0.6915, Train Acc: 0.52085 Valid Loss: 0.6931, Valid Acc: 0.5166
# Epoch 10/100
#  Train Loss: 0.6913, Train Acc: 0.5228 Valid Loss: 0.6930, Valid Acc: 0.5174
# Epoch 11/100
#  Train Loss: 0.6911, Train Acc: 0.5226 Valid Loss: 0.6929, Valid Acc: 0.5178
# Epoch 12/100
#  Train Loss: 0.6909, Train Acc: 0.52485 Valid Loss: 0.6928, Valid Acc: 0.5168
# Epoch 13/100
#  Train Loss: 0.6906, Train Acc: 0.5263 Valid Loss: 0.6928, Valid Acc: 0.5172
# Epoch 14/100
#  Train Loss: 0.6904, Train Acc: 0.5264 Valid Loss: 0.6928, Valid Acc: 0.5186
# Epoch 15/100
#  Train Loss: 0.6901, Train Acc: 0.52925 Valid Loss: 0.6927, Valid Acc: 0.5198
# Epoch 16/100
#  Train Loss: 0.6899, Train Acc: 0.53215 Valid Loss: 0.6926, Valid Acc: 0.5194
# Epoch 17/100
#  Train Loss: 0.6896, Train Acc: 0.5322 Valid Loss: 0.6926, Valid Acc: 0.5202
# Epoch 18/100
#  Train Loss: 0.6893, Train Acc: 0.5332 Valid Loss: 0.6925, Valid Acc: 0.5238
# Epoch 19/100
#  Train Loss: 0.6890, Train Acc: 0.5367 Valid Loss: 0.6924, Valid Acc: 0.529
# Epoch 20/100
#  Train Loss: 0.6887, Train Acc: 0.53995 Valid Loss: 0.6924, Valid Acc: 0.5234
# Epoch 21/100
#  Train Loss: 0.6882, Train Acc: 0.54275 Valid Loss: 0.6922, Valid Acc: 0.5292
# Epoch 22/100
#  Train Loss: 0.6878, Train Acc: 0.5442 Valid Loss: 0.6920, Valid Acc: 0.531
# Epoch 23/100
#  Train Loss: 0.6872, Train Acc: 0.54855 Valid Loss: 0.6919, Valid Acc: 0.5304
# Epoch 24/100
#  Train Loss: 0.6864, Train Acc: 0.5516 Valid Loss: 0.6915, Valid Acc: 0.5354
# Epoch 25/100
#  Train Loss: 0.6854, Train Acc: 0.5533 Valid Loss: 0.6910, Valid Acc: 0.5342
# Epoch 26/100
#  Train Loss: 0.6837, Train Acc: 0.55835 Valid Loss: 0.6898, Valid Acc: 0.5378
# Epoch 27/100
#  Train Loss: 0.6791, Train Acc: 0.57125 Valid Loss: 0.6855, Valid Acc: 0.559
# Epoch 28/100
#  Train Loss: 0.6694, Train Acc: 0.59525 Valid Loss: 0.6749, Valid Acc: 0.595
# Epoch 29/100
#  Train Loss: 0.6646, Train Acc: 0.60685 Valid Loss: 0.6720, Valid Acc: 0.6016
# Epoch 30/100
#  Train Loss: 0.6599, Train Acc: 0.61485 Valid Loss: 0.6665, Valid Acc: 0.6084
# Epoch 31/100
#  Train Loss: 0.6574, Train Acc: 0.6183 Valid Loss: 0.6650, Valid Acc: 0.6094
# Epoch 32/100
#  Train Loss: 0.6541, Train Acc: 0.6253 Valid Loss: 0.6638, Valid Acc: 0.6092
# Epoch 33/100
#  Train Loss: 0.6547, Train Acc: 0.6225 Valid Loss: 0.6613, Valid Acc: 0.6172
# Epoch 34/100
#  Train Loss: 0.6512, Train Acc: 0.6293 Valid Loss: 0.6608, Valid Acc: 0.618
# Epoch 35/100
#  Train Loss: 0.6479, Train Acc: 0.6341 Valid Loss: 0.6603, Valid Acc: 0.6156
# Epoch 36/100
#  Train Loss: 0.6479, Train Acc: 0.63255 Valid Loss: 0.6619, Valid Acc: 0.6116
# Epoch 37/100
#  Train Loss: 0.6461, Train Acc: 0.6359 Valid Loss: 0.6566, Valid Acc: 0.6284
# Epoch 38/100
#  Train Loss: 0.6439, Train Acc: 0.6387 Valid Loss: 0.6590, Valid Acc: 0.6178
# Epoch 39/100
#  Train Loss: 0.6431, Train Acc: 0.63945 Valid Loss: 0.6539, Valid Acc: 0.6314
# Epoch 40/100
#  Train Loss: 0.6404, Train Acc: 0.64635 Valid Loss: 0.6567, Valid Acc: 0.6214
# Epoch 41/100
#  Train Loss: 0.6384, Train Acc: 0.64885 Valid Loss: 0.6550, Valid Acc: 0.6234
# Epoch 42/100
#  Train Loss: 0.6379, Train Acc: 0.64875 Valid Loss: 0.6499, Valid Acc: 0.6392
# Epoch 43/100
#  Train Loss: 0.6356, Train Acc: 0.6505 Valid Loss: 0.6521, Valid Acc: 0.6308
# Epoch 44/100
#  Train Loss: 0.6332, Train Acc: 0.6537 Valid Loss: 0.6472, Valid Acc: 0.6436
# Epoch 45/100
#  Train Loss: 0.6324, Train Acc: 0.655 Valid Loss: 0.6475, Valid Acc: 0.6382
# Epoch 46/100
#  Train Loss: 0.6302, Train Acc: 0.6598 Valid Loss: 0.6465, Valid Acc: 0.6402
# Epoch 47/100
#  Train Loss: 0.6282, Train Acc: 0.6617 Valid Loss: 0.6450, Valid Acc: 0.6424
# Epoch 48/100
#  Train Loss: 0.6273, Train Acc: 0.6614 Valid Loss: 0.6422, Valid Acc: 0.645
# Epoch 49/100
#  Train Loss: 0.6274, Train Acc: 0.66095 Valid Loss: 0.6446, Valid Acc: 0.6448
# Epoch 50/100
#  Train Loss: 0.6233, Train Acc: 0.6667 Valid Loss: 0.6409, Valid Acc: 0.6474
# Epoch 51/100
#  Train Loss: 0.6206, Train Acc: 0.66935 Valid Loss: 0.6372, Valid Acc: 0.6534
# Epoch 52/100
#  Train Loss: 0.6189, Train Acc: 0.6733 Valid Loss: 0.6343, Valid Acc: 0.6598
# Epoch 53/100
#  Train Loss: 0.6176, Train Acc: 0.67335 Valid Loss: 0.6328, Valid Acc: 0.6612
# Epoch 54/100
#  Train Loss: 0.6141, Train Acc: 0.6782 Valid Loss: 0.6328, Valid Acc: 0.6576
# Epoch 55/100
#  Train Loss: 0.6132, Train Acc: 0.67955 Valid Loss: 0.6329, Valid Acc: 0.6608
# Epoch 56/100
#  Train Loss: 0.6110, Train Acc: 0.6812 Valid Loss: 0.6310, Valid Acc: 0.6612
# Epoch 57/100
#  Train Loss: 0.6079, Train Acc: 0.6857 Valid Loss: 0.6287, Valid Acc: 0.6646
# Epoch 58/100
#  Train Loss: 0.6070, Train Acc: 0.68555 Valid Loss: 0.6245, Valid Acc: 0.6716
# Epoch 59/100
#  Train Loss: 0.6048, Train Acc: 0.68915 Valid Loss: 0.6256, Valid Acc: 0.6698
# Epoch 60/100
#  Train Loss: 0.6034, Train Acc: 0.69065 Valid Loss: 0.6240, Valid Acc: 0.6722
# Epoch 61/100
#  Train Loss: 0.6009, Train Acc: 0.69195 Valid Loss: 0.6208, Valid Acc: 0.6764
# Epoch 62/100
#  Train Loss: 0.5986, Train Acc: 0.69515 Valid Loss: 0.6270, Valid Acc: 0.6684
# Epoch 63/100
#  Train Loss: 0.5992, Train Acc: 0.69465 Valid Loss: 0.6209, Valid Acc: 0.6736
# Epoch 64/100
#  Train Loss: 0.5974, Train Acc: 0.69585 Valid Loss: 0.6189, Valid Acc: 0.6772
# Epoch 65/100
#  Train Loss: 0.5938, Train Acc: 0.6998 Valid Loss: 0.6189, Valid Acc: 0.6784
# Epoch 66/100
#  Train Loss: 0.5928, Train Acc: 0.7002 Valid Loss: 0.6181, Valid Acc: 0.6782
# Epoch 67/100
#  Train Loss: 0.5918, Train Acc: 0.7007 Valid Loss: 0.6170, Valid Acc: 0.6814
# Epoch 68/100
#  Train Loss: 0.5905, Train Acc: 0.7029 Valid Loss: 0.6269, Valid Acc: 0.6666
# Epoch 69/100
#  Train Loss: 0.5903, Train Acc: 0.70225 Valid Loss: 0.6133, Valid Acc: 0.6866
# Epoch 70/100
#  Train Loss: 0.5879, Train Acc: 0.70695 Valid Loss: 0.6134, Valid Acc: 0.6856
# Epoch 71/100
#  Train Loss: 0.5888, Train Acc: 0.7048 Valid Loss: 0.6159, Valid Acc: 0.6852
# Epoch 72/100
#  Train Loss: 0.5857, Train Acc: 0.70805 Valid Loss: 0.6104, Valid Acc: 0.6878
# Epoch 73/100
#  Train Loss: 0.5853, Train Acc: 0.70885 Valid Loss: 0.6107, Valid Acc: 0.6872
# Epoch 74/100
#  Train Loss: 0.5849, Train Acc: 0.7084 Valid Loss: 0.6098, Valid Acc: 0.6868
# Epoch 75/100
#  Train Loss: 0.5819, Train Acc: 0.71265 Valid Loss: 0.6079, Valid Acc: 0.6928
# Epoch 76/100
#  Train Loss: 0.5829, Train Acc: 0.7107 Valid Loss: 0.6084, Valid Acc: 0.69
# Epoch 77/100
#  Train Loss: 0.5804, Train Acc: 0.7134 Valid Loss: 0.6103, Valid Acc: 0.688
# Epoch 78/100
#  Train Loss: 0.5836, Train Acc: 0.71045 Valid Loss: 0.6072, Valid Acc: 0.6912
# Epoch 79/100
#  Train Loss: 0.5788, Train Acc: 0.71525 Valid Loss: 0.6063, Valid Acc: 0.6916
# Epoch 80/100
#  Train Loss: 0.5773, Train Acc: 0.71645 Valid Loss: 0.6060, Valid Acc: 0.6926
# Epoch 81/100
#  Train Loss: 0.5768, Train Acc: 0.71695 Valid Loss: 0.6084, Valid Acc: 0.6908
# Epoch 82/100
#  Train Loss: 0.5766, Train Acc: 0.71765 Valid Loss: 0.6070, Valid Acc: 0.6954
# Epoch 83/100
#  Train Loss: 0.5754, Train Acc: 0.71805 Valid Loss: 0.6045, Valid Acc: 0.694
# Epoch 84/100
#  Train Loss: 0.5755, Train Acc: 0.71855 Valid Loss: 0.6091, Valid Acc: 0.6936
# Epoch 85/100
#  Train Loss: 0.5757, Train Acc: 0.7173 Valid Loss: 0.6025, Valid Acc: 0.6944
# Epoch 86/100
#  Train Loss: 0.5735, Train Acc: 0.71965 Valid Loss: 0.6016, Valid Acc: 0.697
# Epoch 87/100
#  Train Loss: 0.5706, Train Acc: 0.72205 Valid Loss: 0.6019, Valid Acc: 0.6936
# Epoch 88/100
#  Train Loss: 0.5717, Train Acc: 0.7215 Valid Loss: 0.6017, Valid Acc: 0.6968
# Epoch 89/100
#  Train Loss: 0.5705, Train Acc: 0.7224 Valid Loss: 0.6011, Valid Acc: 0.6974
# Epoch 90/100
#  Train Loss: 0.5701, Train Acc: 0.72225 Valid Loss: 0.6008, Valid Acc: 0.697
# Epoch 91/100
#  Train Loss: 0.5687, Train Acc: 0.72395 Valid Loss: 0.6001, Valid Acc: 0.699
# Epoch 92/100
#  Train Loss: 0.5690, Train Acc: 0.7233 Valid Loss: 0.5999, Valid Acc: 0.6994
# Epoch 93/100
#  Train Loss: 0.5699, Train Acc: 0.7229 Valid Loss: 0.6042, Valid Acc: 0.6948
# Epoch 94/100
#  Train Loss: 0.5687, Train Acc: 0.72435 Valid Loss: 0.5993, Valid Acc: 0.6982
# Epoch 95/100
#  Train Loss: 0.5677, Train Acc: 0.7252 Valid Loss: 0.5973, Valid Acc: 0.7012
# Epoch 96/100
#  Train Loss: 0.5671, Train Acc: 0.7257 Valid Loss: 0.5982, Valid Acc: 0.7006
# Epoch 97/100
#  Train Loss: 0.5652, Train Acc: 0.72555 Valid Loss: 0.5984, Valid Acc: 0.7014
# Epoch 98/100
#  Train Loss: 0.5643, Train Acc: 0.7276 Valid Loss: 0.5975, Valid Acc: 0.7028
# Epoch 99/100
#  Train Loss: 0.5635, Train Acc: 0.72905 Valid Loss: 0.5973, Valid Acc: 0.7032
# Epoch 100/100
#  Train Loss: 0.5630, Train Acc: 0.7302 Valid Loss: 0.6067, Valid Acc: 0.692

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    'train_loss': trian_losses,
    'val_loss': val_losses,
    'train_acc': train_accs,
    'val_accs': val_accs
})

df.plot()
plt.show()

# %%
def evaluate_model(model, test_dataloader, criterion, device):
    model.to(device).eval()
    test_loss, test_correct, test_total = 0, 0, 0
    with torch.no_grad():
        for test_inputs, test_labels in test_dataloader:
            test_inputs = test_inputs.to(device).float()
            test_labels = test_labels.to(device).float()

            output = model(test_inputs)
            loss = criterion(output, test_labels)

            test_loss += loss.item()
            p = torch.sigmoid(output)
            pred = (p >= 0.5).float()
            test_correct += (pred == test_labels).sum().item()
            test_total += test_labels.size(0)

        test_loss = test_loss / len(test_dataloader)
        test_acc = test_correct / test_total
    return test_loss, test_acc

test_dataset = TensorDataset(X_test_onehot, y_test)
test_dataloader = DataLoader(test_dataset, batch_size, shuffle=False)

test_loss, test_acc = evaluate_model(model, test_dataloader, criterion, device)
print(f'Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.4f}')
# Out:
# Test Loss: 0.6015, Test Acc: 0.6938
