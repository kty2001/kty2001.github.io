# %% [markdown]
# # 토큰화 (Tokenization)
#
# - 문장이나 단어를 더 작은 단위로 나누어 분석 가능한 단위(토큰, Token)으로 변환하는 과정
# - 토큰의 단위가 상황에 따라 다르지만, 보통 의미있는 혹은 처리하는 단위로써 토큰 정의
# - 자연어 처리에서 크롤링, 데이터 수집 등으로 얻은 코퍼스 데이터는 정제되지 않은 경우가 많은데 이를 사용 용도에 맞게 토큰화, 정제, 정규화하는 과정이 필요
#
# **토큰화 목적**
#
# - 문법적 구조 이해
# - 유연한 데이터 활용

# %%
# !pip install torch torchvision
# Out:
# Requirement already satisfied: torch in .\nlp_venv\Lib\site-packages (2.13.0)
# Requirement already satisfied: torchvision in .\nlp_venv\Lib\site-packages (0.28.0)
# Requirement already satisfied: filelock in .\nlp_venv\Lib\site-packages (from torch) (3.32.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\nlp_venv\Lib\site-packages (from torch) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in .\nlp_venv\Lib\site-packages (from torch) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\nlp_venv\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\nlp_venv\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in .\nlp_venv\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\nlp_venv\Lib\site-packages (from torch) (2026.7.0)
# Requirement already satisfied: numpy in .\nlp_venv\Lib\site-packages (from torchvision) (2.5.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in .\nlp_venv\Lib\site-packages (from torchvision) (12.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\nlp_venv\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\nlp_venv\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
# !pip install transformers spacy kss konlpy tensorflow ipywidgets tqdm
# Out:
# Requirement already satisfied: transformers in .\nlp_venv\Lib\site-packages (5.14.1)
# Requirement already satisfied: spacy in .\nlp_venv\Lib\site-packages (3.8.14)
# Requirement already satisfied: kss in .\nlp_venv\Lib\site-packages (6.0.6)
# Requirement already satisfied: konlpy in .\nlp_venv\Lib\site-packages (0.6.0)
# Requirement already satisfied: tensorflow in .\nlp_venv\Lib\site-packages (2.21.0)
# Requirement already satisfied: ipywidgets in .\nlp_venv\Lib\site-packages (8.1.8)
# Requirement already satisfied: tqdm in .\nlp_venv\Lib\site-packages (4.70.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in .\nlp_venv\Lib\site-packages (from transformers) (1.26.1)
# Requirement already satisfied: numpy>=1.17 in .\nlp_venv\Lib\site-packages (from transformers) (2.5.1)
# Requirement already satisfied: packaging>=20.0 in .\nlp_venv\Lib\site-packages (from transformers) (26.3)
# Requirement already satisfied: pyyaml>=5.1 in .\nlp_venv\Lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in .\nlp_venv\Lib\site-packages (from transformers) (2026.7.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\nlp_venv\Lib\site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in .\nlp_venv\Lib\site-packages (from transformers) (0.27.1)
# Requirement already satisfied: safetensors>=0.8.0 in .\nlp_venv\Lib\site-packages (from transformers) (0.8.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in .\nlp_venv\Lib\site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.16.0)
# Requirement already satisfied: colorama in .\nlp_venv\Lib\site-packages (from click<9.0.0,>=8.4.2->huggingface-hub<2.0,>=1.5.0->transformers) (0.4.6)
# Requirement already satisfied: anyio in .\nlp_venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.14.2)
# Requirement already satisfied: certifi in .\nlp_venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in .\nlp_venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in .\nlp_venv\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in .\nlp_venv\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in .\nlp_venv\Lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in .\nlp_venv\Lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in .\nlp_venv\Lib\site-packages (from spacy) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in .\nlp_venv\Lib\site-packages (from spacy) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in .\nlp_venv\Lib\site-packages (from spacy) (3.0.13)
# Requirement already satisfied: thinc<8.4.0,>=8.3.12 in .\nlp_venv\Lib\site-packages (from spacy) (8.3.13)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in .\nlp_venv\Lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.5.3 in .\nlp_venv\Lib\site-packages (from spacy) (2.5.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in .\nlp_venv\Lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<2.0.0,>=1.0.0 in .\nlp_venv\Lib\site-packages (from spacy) (1.0.0)
# Requirement already satisfied: confection<2.0.0,>=1.3.2 in .\nlp_venv\Lib\site-packages (from spacy) (1.3.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in .\nlp_venv\Lib\site-packages (from spacy) (2.34.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in .\nlp_venv\Lib\site-packages (from spacy) (2.13.4)
# Requirement already satisfied: jinja2 in .\nlp_venv\Lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in .\nlp_venv\Lib\site-packages (from spacy) (83.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in .\nlp_venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in .\nlp_venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in .\nlp_venv\Lib\site-packages (from pydantic<3.0.0,>=2.0.0->spacy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\nlp_venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in .\nlp_venv\Lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.7.0)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in .\nlp_venv\Lib\site-packages (from thinc<8.4.0,>=8.3.12->spacy) (1.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in .\nlp_venv\Lib\site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in .\nlp_venv\Lib\site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in .\nlp_venv\Lib\site-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: cloudpathlib>=0.7.0 in .\nlp_venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (0.24.0)
# Requirement already satisfied: smart-open>=5.2.1 in .\nlp_venv\Lib\site-packages (from weasel<2.0.0,>=1.0.0->spacy) (8.0.1)
# Requirement already satisfied: emoji==1.2.0 in .\nlp_venv\Lib\site-packages (from kss) (1.2.0)
# Requirement already satisfied: pecab in .\nlp_venv\Lib\site-packages (from kss) (1.0.8)
# Requirement already satisfied: networkx in .\nlp_venv\Lib\site-packages (from kss) (3.6.1)
# Requirement already satisfied: jamo in .\nlp_venv\Lib\site-packages (from kss) (0.4.1)
# Requirement already satisfied: hangul-jamo in .\nlp_venv\Lib\site-packages (from kss) (1.0.1)
# Requirement already satisfied: tossi in .\nlp_venv\Lib\site-packages (from kss) (0.3.1)
# Requirement already satisfied: distance in .\nlp_venv\Lib\site-packages (from kss) (0.1.3)
# Requirement already satisfied: unidecode in .\nlp_venv\Lib\site-packages (from kss) (1.4.0)
# Requirement already satisfied: cmudict in .\nlp_venv\Lib\site-packages (from kss) (1.1.3)
# Requirement already satisfied: koparadigm in .\nlp_venv\Lib\site-packages (from kss) (0.10.0)
# Requirement already satisfied: kollocate in .\nlp_venv\Lib\site-packages (from kss) (0.0.2)
# Requirement already satisfied: bs4 in .\nlp_venv\Lib\site-packages (from kss) (0.0.2)
# Requirement already satisfied: pytest in .\nlp_venv\Lib\site-packages (from kss) (9.1.1)
# Requirement already satisfied: scipy in .\nlp_venv\Lib\site-packages (from kss) (1.18.0)
# Requirement already satisfied: JPype1>=0.7.0 in .\nlp_venv\Lib\site-packages (from konlpy) (1.7.1)
# Requirement already satisfied: lxml>=4.1.0 in .\nlp_venv\Lib\site-packages (from konlpy) (6.1.1)
# Requirement already satisfied: absl-py>=1.0.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in .\nlp_venv\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in .\nlp_venv\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in .\nlp_venv\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in .\nlp_venv\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in .\nlp_venv\Lib\site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: six>=1.12.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wrapt>=1.11.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in .\nlp_venv\Lib\site-packages (from tensorflow) (1.83.0)
# Requirement already satisfied: keras>=3.12.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in .\nlp_venv\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in .\nlp_venv\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: comm>=0.1.3 in .\nlp_venv\Lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in .\nlp_venv\Lib\site-packages (from ipywidgets) (9.16.1)
# Requirement already satisfied: traitlets>=4.3.1 in .\nlp_venv\Lib\site-packages (from ipywidgets) (5.16.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in .\nlp_venv\Lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in .\nlp_venv\Lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in .\nlp_venv\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.53)
# Requirement already satisfied: psutil>=7 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in .\nlp_venv\Lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in .\nlp_venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in .\nlp_venv\Lib\site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.7)
# Requirement already satisfied: namex in .\nlp_venv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in .\nlp_venv\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\nlp_venv\Lib\site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: mdurl~=0.1 in .\nlp_venv\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in .\nlp_venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in .\nlp_venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.2)
# Requirement already satisfied: pure-eval in .\nlp_venv\Lib\site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in .\nlp_venv\Lib\site-packages (from bs4->kss) (4.15.0)
# Requirement already satisfied: soupsieve>=1.6.1 in .\nlp_venv\Lib\site-packages (from beautifulsoup4->bs4->kss) (2.9.2)
# Requirement already satisfied: importlib-metadata>=5 in .\nlp_venv\Lib\site-packages (from cmudict->kss) (9.0.0)
# Requirement already satisfied: importlib-resources>=5 in .\nlp_venv\Lib\site-packages (from cmudict->kss) (7.1.0)
# Requirement already satisfied: zipp>=3.20 in .\nlp_venv\Lib\site-packages (from importlib-metadata>=5->cmudict->kss) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\nlp_venv\Lib\site-packages (from jinja2->spacy) (3.0.3)
# Requirement already satisfied: whoosh in .\nlp_venv\Lib\site-packages (from kollocate->kss) (2.7.4)
# Requirement already satisfied: xlrd==1.2.0 in .\nlp_venv\Lib\site-packages (from koparadigm->kss) (1.2.0)
# Requirement already satisfied: pyarrow in .\nlp_venv\Lib\site-packages (from pecab->kss) (25.0.0)
# Requirement already satisfied: iniconfig>=1.0.1 in .\nlp_venv\Lib\site-packages (from pytest->kss) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in .\nlp_venv\Lib\site-packages (from pytest->kss) (1.6.0)
# Requirement already satisfied: bidict in .\nlp_venv\Lib\site-packages (from tossi->kss) (0.23.1)

# %%
import nltk
from tqdm.auto import tqdm

nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\playdata2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\playdata2\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
text = 'NLP is fascinating. It has many applications in real-world scenarios.'

# %%
print(nltk.word_tokenize(text))
print(nltk.sent_tokenize(text))

for sent in nltk.sent_tokenize(text):
    print(nltk.word_tokenize(sent))
# Out:
# ['NLP', 'is', 'fascinating', '.', 'It', 'has', 'many', 'applications', 'in', 'real-world', 'scenarios', '.']
# ['NLP is fascinating.', 'It has many applications in real-world scenarios.']
# ['NLP', 'is', 'fascinating', '.']
# ['It', 'has', 'many', 'applications', 'in', 'real-world', 'scenarios', '.']

# %% [markdown]
# ### Subword Tokenization
#
# - BertTokenizer
#     - 단어를 부분 단위로 쪼개어 희귀하거나 새로운 단어도 부분적으로 표현할 수 있도록 함 -> 어휘 크기를 줄이고 다양한 언어 패턴 학습 가능

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
word = 'unhappiness'
subwords = tokenizer.tokenize(word)
subwords
# Out:
# ['un', '##ha', '##pp', '##iness']

# %% [markdown]
# BERT 서브워드 토큰화 규칙
# - 단어를 사전에 있는 조각(subword)들로 쪼개서 표현한다.
# - 단어의 처음 조각은 그대로, 단어 중간/뒤에서 이어지는 조각은 ## 붙여서 표시
# - 통째 단어 없으면 가장 긴 조각부터 맞춰서 쪼개고, 끝까지 조각이 안맞으면 [UNK](모르는 토큰)으로 처리
# -> [OOV](처음 보는 단어)를 줄이고 희귀 단어도 조각 조합으로 다룰 수 있게 된다
#
# Warning: You are sending unauthenticated requests to the HF Hub ... -> 허깅페이스 로그인

# %%
list(word)
# Out:
# ['u', 'n', 'h', 'a', 'p', 'p', 'i', 'n', 'e', 's', 's']

# %%
import re

re.findall(r'\b\w+\b', text)
# Out:
# ['NLP',
#  'is',
#  'fascinating',
#  'It',
#  'has',
#  'many',
#  'applications',
#  'in',
#  'real',
#  'world',
#  'scenarios']

# %%
from nltk.tokenize import WordPunctTokenizer, word_tokenize

text = "Don't hesitate to use well-being practices for self-care."
word_punct_tokenizer = WordPunctTokenizer()
print(word_punct_tokenizer.tokenize(text))
print(word_tokenize(text))
# Out:
# ['Don', "'", 't', 'hesitate', 'to', 'use', 'well', '-', 'being', 'practices', 'for', 'self', '-', 'care', '.']
# ['Do', "n't", 'hesitate', 'to', 'use', 'well-being', 'practices', 'for', 'self-care', '.']

# %% [markdown]
# WordPunctTokenizer는 ',- 같은 구두점 기준으로 더 잘게 토큰화
# word_tokenize는 상대적으로 조금 더 자연스러운 단어 단위로 토큰화

# %%
from nltk.tokenize import TreebankWordTokenizer, word_tokenize
text = "Don't hesitate to use well-being practices for self-care. NLP is fascinating. It has many applications in real-world scenarios."

treebank_word_tokenizer = TreebankWordTokenizer()
print(treebank_word_tokenizer.tokenize(text))
print(word_tokenize(text))
# Out:
# ['Do', "n't", 'hesitate', 'to', 'use', 'well-being', 'practices', 'for', 'self-care.', 'NLP', 'is', 'fascinating.', 'It', 'has', 'many', 'applications', 'in', 'real-world', 'scenarios', '.']
# ['Do', "n't", 'hesitate', 'to', 'use', 'well-being', 'practices', 'for', 'self-care', '.', 'NLP', 'is', 'fascinating', '.', 'It', 'has', 'many', 'applications', 'in', 'real-world', 'scenarios', '.']

# %% [markdown]
# 토크나이저마다 각자의 규칙으로 토큰화
# 보통 차이나는 부분은 구두점/기호 처리 방식에서 분리 결과 차이남

# %%
import kss

text = "이 눈깔! 이 눈깔! 왜 나를 똑바루 바라보지 못하고 천장만 바라 보느냐! 응?! 설렁탕을 사왔는데… 왜 먹지를 못하니? 왜 먹지를 못하니! 괴상하게도 오늘은 운수가 좋더니만…"

kss.split_sentences(text)
# Out:
# ['이 눈깔!',
#  '이 눈깔!',
#  '왜 나를 똑바루 바라보지 못하고 천장만 바라 보느냐!',
#  '응?!',
#  '설렁탕을 사왔는데… 왜 먹지를 못하니?',
#  '왜 먹지를 못하니!',
#  '괴상하게도 오늘은 운수가 좋더니만…']

# %% [markdown]
# ### 품사 태깅
#
# **pos_tag**
#
# pos_tag는 자연어 처리(NLP)에서 단어에 품사를 태깅하는 함수로, 주로 NLTK와 같은 라이브러리에서 사용된다.
#
# - nltk pos_tag() 주요 품사 태깅<br>
#
# 1. **NN (Noun, Singular)**
#    단수 명사를 나타낸다. 하나의 사물이나 개념을 지칭한다.
#    예시: "cat", "book", "apple"
#
# 2. **NNS (Noun, Plural)**
#    복수 명사를 나타낸다. 두 개 이상의 사물이나 개념을 지칭한다.
#    예시: "cats", "books", "apples"
#
# 3. **NNP (Proper Noun, Singular)**
#    단수 고유 명사를 나타낸다. 특정한 사람, 장소 또는 조직의 이름을 지칭한다.
#    예시: "Alice", "London", "NASA"
#
# 4. **NNPS (Proper Noun, Plural)**
#    복수 고유 명사를 나타낸다. 두 개 이상의 특정한 사람, 장소 또는 조직의 이름을 지칭한다.
#    예시: "Smiths", "United Nations"
#
# 5. **VB (Verb, Base Form)**
#    동사의 원형을 나타낸다. 일반적으로 현재 시제와 함께 사용된다.
#    예시: "run", "eat", "play"
#
# 6. **VBD (Verb, Past Tense)**
#    동사의 과거형을 나타낸다.
#    예시: "ran", "ate", "played"
#
# 7. **VBG (Verb, Gerund or Present Participle)**
#    동명사 또는 현재 분사를 나타낸다. 일반적으로 "-ing" 형태이다.
#    예시: "running", "eating", "playing"
#
# 8. **VBN (Verb, Past Participle)**
#    동사의 과거 분사형을 나타낸다. 주로 완료 시제와 함께 사용된다.
#    예시: "run" (as in "has run"), "eaten", "played"
#
# 9. **VBZ (Verb, 3rd Person Singular Present)**
#    3인칭 단수 현재형 동사를 나타낸다. 주어가 3인칭 단수일 때 사용된다.
#    예시: "runs", "eats", "plays"
#
# 10. **JJ (Adjective)**
#     형용사를 나타낸다. 명사를 수식하여 그 특성을 설명한다.
#     예시: "big", "blue", "happy"
#
# 11. **JJR (Adjective, Comparative)**
#     비교급 형용사를 나타낸다. 두 개의 대상을 비교할 때 사용된다.
#     예시: "bigger", "bluer", "happier"
#
# 12. **JJS (Adjective, Superlative)**
#     최상급 형용사를 나타낸다. 세 개 이상의 대상을 비교할 때 사용된다.
#     예시: "biggest", "bluest", "happiest"
#
# 13. **RB (Adverb)**
#     부사를 나타낸다. 동사, 형용사 또는 다른 부사를 수식한다.
#     예시: "quickly", "very", "well"
#
# 14. **RBR (Adverb, Comparative)**
#     비교급 부사를 나타낸다. 두 개의 대상을 비교할 때 사용된다.
#     예시: "more quickly", "better"
#
# 15. **RBS (Adverb, Superlative)**
#     최상급 부사를 나타낸다. 세 개 이상의 대상을 비교할 때 사용된다.
#     예시: "most quickly", "best"
#
# 16. **IN (Preposition or Subordinating Conjunction)**
#     전치사 또는 종속 접속사를 나타낸다. 명사와의 관계를 나타내거나 종속절을 시작한다.
#     예시: "in", "on", "because"
#
# 17. **DT (Determiner)**
#     한정사를 나타낸다. 명사의 수와 상태를 정의한다.
#     예시: "the", "a", "some"
#
# 18. **PRP (Personal Pronoun)**
#     인칭 대명사를 나타낸다. 사람, 사물 등을 대체할 때 사용된다.
#     예시: "I", "you", "he", "they"
#
# 19. **PRP$ (Possessive Pronoun)**
#     소유 대명사를 나타낸다. 소유 관계를 나타낸다.
#     예시: "my", "your", "his", "their"

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\playdata2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\playdata2\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
# True

# %%
from nltk.tag import pos_tag

text = 'Time flies like an arrow.'
tokens = word_tokenize(text)
print(tokens)
pos_tags = pos_tag(tokens)
pos_tags
# Out:
# ['Time', 'flies', 'like', 'an', 'arrow', '.']
# [('Time', 'NNP'),
#  ('flies', 'NNS'),
#  ('like', 'IN'),
#  ('an', 'DT'),
#  ('arrow', 'NN'),
#  ('.', '.')]

# %% [markdown]
# spacy 주요 품사 태깅
#
# | 태그 | 설명                 | 예시                 |
# |------|----------------------|----------------------|
# | ADJ  | 형용사               | big, nice           |
# | ADP  | 전치사               | in, to, on          |
# | ADV  | 부사                 | very, well          |
# | AUX  | 조동사               | is, have (조동사로 사용될 때) |
# | CONJ | 접속사               | and, or             |
# | DET  | 한정사/관사          | the, a              |
# | INTJ | 감탄사               | oh, wow             |
# | NOUN | 명사                 | dog, table          |
# | NUM  | 숫자                 | one, two, 3         |
# | PART | 소사                 | 'to' (to fly에서), not |
# | PRON | 대명사               | he, she, it         |
# | PROPN| 고유명사             | John, France        |
# | PUNCT| 구두점               | ., !, ?             |
# | SCONJ| 종속 접속사          | because, if         |
# | SYM  | 기호                 | $, %, @             |
# | VERB | 동사                 | run, eat            |
# | X    | 알 수 없는 품사       | 외국어 단어, 잘못된 형식 |

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---- ----------------------------------- 1.6/12.8 MB 13.9 MB/s eta 0:00:01
#      ---------------- ----------------------- 5.2/12.8 MB 16.0 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 15.3 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 16.8 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 14.9 MB/s  0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

spacy_nlp = spacy.load('en_core_web_sm')

# %%
tokens = spacy_nlp(text)

for token in tokens:
    print(token.text, ":", token.pos_)
# Out:
# Time : NOUN
# flies : VERB
# like : ADP
# an : DET
# arrow : NOUN
# . : PUNCT

# %% [markdown]
# ### KoNLPy
#
# - 한국어 자연어 처리를 위한 라이브러리
# - 형태소 분석, 품사 태깅, 텍스트 전처리 등 기능 지원
# - 여러 형태소 분석기 중 적합한 분석기 선택 가능

# %%
from konlpy.tag import Okt

text = "이 눈깔! 이 눈깔! 왜 나를 똑바루 바라보지 못하고 천장만 바라 보느냐! 응?! 설렁탕을 사왔는데… 왜 먹지를 못하니? 왜 먹지를 못하니! 괴상하게도 오늘은 운수가 좋더니만…"

okt = Okt()

morphs = okt.morphs(text)
morphs
# Out:
# ['이',
#  '눈',
#  '깔',
#  '!',
#  '이',
#  '눈',
#  '깔',
#  '!',
#  '왜',
#  '나를',
#  '똑바루',
#  '바라보지',
#  '못',
#  '하고',
#  '천장',
#  '만',
#  '바라',
#  '보느냐',
#  '!',
#  '응',
#  '?!',
#  '설렁탕',
#  '을',
#  '사왔는데',
#  '…',
#  '왜',
#  '먹지를',
#  '못',
#  '하니',
#  '?',
#  '왜',
#  '먹지를',
#  '못',
#  '하니',
#  '!',
#  '괴상하게도',
#  '오늘',
#  '은',
#  '운수',
#  '가',
#  '좋더니만',
#  '…']

# %%
pos_tags = okt.pos(text)
pos_tags
# Out:
# [('이', 'Noun'),
#  ('눈', 'Noun'),
#  ('깔', 'Verb'),
#  ('!', 'Punctuation'),
#  ('이', 'Noun'),
#  ('눈', 'Noun'),
#  ('깔', 'Verb'),
#  ('!', 'Punctuation'),
#  ('왜', 'Noun'),
#  ('나를', 'Verb'),
#  ('똑바루', 'Noun'),
#  ('바라보지', 'Verb'),
#  ('못', 'Noun'),
#  ('하고', 'Josa'),
#  ('천장', 'Noun'),
#  ('만', 'Josa'),
#  ('바라', 'Verb'),
#  ('보느냐', 'Verb'),
#  ('!', 'Punctuation'),
#  ('응', 'Noun'),
#  ('?!', 'Punctuation'),
#  ('설렁탕', 'Noun'),
#  ('을', 'Josa'),
#  ('사왔는데', 'Verb'),
#  ('…', 'Punctuation'),
#  ('왜', 'Noun'),
#  ('먹지를', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하니', 'Verb'),
#  ('?', 'Punctuation'),
#  ('왜', 'Noun'),
#  ('먹지를', 'Verb'),
#  ('못', 'VerbPrefix'),
#  ('하니', 'Verb'),
#  ('!', 'Punctuation'),
#  ('괴상하게도', 'Adjective'),
#  ('오늘', 'Noun'),
#  ('은', 'Josa'),
#  ('운수', 'Noun'),
#  ('가', 'Josa'),
#  ('좋더니만', 'Adjective'),
#  ('…', 'Punctuation')]

# %%
nouns = okt.nouns(text)
nouns
# Out:
# ['이', '눈', '이', '눈', '왜', '똑바루', '못', '천장', '응', '설렁탕', '왜', '왜', '오늘', '운수']
