# %% [markdown]
# # Metadata Filtering
# - 벡터 유사도 계산 전에(또는 함께) 문서의 메타데이터 조건으로 검색 대상을 제한하는 기법

# %%
# %pip install -U langchain langchain-classic langchain-community langchain-core langchain-openai langchain-pinecone lark
# Out:
# Requirement already satisfied: langchain in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (1.3.18)
# Requirement already satisfied: langchain-classic in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (1.0.8)
# Requirement already satisfied: langchain-community in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-core in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (1.6.1)
# Requirement already satisfied: langchain-openai in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (1.6.0)
# Requirement already satisfied: langchain-pinecone in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (0.2.13)
# Requirement already satisfied: lark in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (1.3.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-core) (0.17.0)
# Requirement already satisfied: anyio in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (4.14.2)
# Requirement already satisfied: certifi in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (1.0.9)
# Requirement already satisfied: idna in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx<1.0.0,>=0.23.0->langchain-core) (3.19)
# Requirement already satisfied: h11>=0.16 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (16.1.1)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-classic) (1.1.2)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-classic) (2.0.52)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.5.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.5.5)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-community) (3.14.3)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-community) (2.5.2)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-community) (2.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.5)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.3)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-openai) (3.3.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-openai) (0.14.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.12.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: httpcore2==2.12.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.12.0)
# Requirement already satisfied: truststore>=0.10 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.4)
# Requirement already satisfied: regex in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: pinecone<8.0.0,>=6.0.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (7.3.0)
# Requirement already satisfied: simsimd>=5.9.11 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from langchain-pinecone) (6.5.16)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.0.post0)
# Requirement already satisfied: aiohttp-retry<3.0.0,>=2.9.1 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (2.9.1)
# Requirement already satisfied: six>=1.5 in c:\Users\playdata2\LLM\llm_venv\Lib\site-packages (from python-dateutil>=2.5.3->pinecone<8.0.0,>=6.0.0->pinecone[asyncio]<8.0.0,>=6.0.0->langchain-pinecone) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv
import os

load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['PINECONE_API_KEY'] = os.getenv('PINECONE_API_KEY')
os.environ['COHERE_API_KEY'] = os.getenv('COHERE_API_KEY')

os.environ['LANGSMITH_TRACING'] = 'true'
os.environ['LANGSMITH_ENDPOINT'] = 'https://apac.api.smith.langchain.com'
os.environ['LANGSMITH_PROJECT'] = 'skn34-langchain'
os.environ['LANGSMITH_API_KEY'] = os.getenv('LANGSMITH_API_KEY')

# %%
import pandas as pd

document_df = pd.read_csv('documents_meta.csv')
document_df
# Out:
#    doc_id                      title  \
# 0      D1                 제주도 여행 가이드
# 1      D2         전주 비빔밥과 진주 비빔밥 차이점
# 2      D3                걸스데이 히트곡 분석
# 3      D4                 세종대왕과 훈민정음
# 4      D5              이순신 장군의 명량 해전
# 5      D6         2024년 기후 변화 종합 보고서
# 6      D7              AI 기술 동향 및 윤리
# 7      D8              서울 지하철 이용 가이드
# 8      D9            판소리 “춘향가” 서사 구조
# 9     D10            한국 축구 대표팀 주요 기록
# 10    D11               건강한 생활습관 가이드
# 11    D12             서울 근교 당일치기 여행지
# 12    D13            전국 비빔밥 영양 성분 분석
# 13    D14          AI 기반 기후 예측 연구 사례
# 14    D15             한국 전통 음악 “가야금”
# 15    D16                한국 전통 혼례 풍습
# 16    D17       2023년 한국 영화 흥행 Top10
# 17    D18        윈도우즈에서 한글 시각화 설정 방법
# 18    D19             코드 악취와 리팩토링 개요
# 19    D20         JUnit5와 JUnit4 차이점
# 20    D21     Wheel of Fortune 게임 구조
# 21    D22              싱글톤 디자인 패턴 예제
# 22    D23             Strategy 패턴 설명
# 23    D24           Command 패턴 적용 사례
# 24    D25         2025년 한국 AI 정책 보고서
# 25    D26            딥러닝 기반 기상 예측 모델
# 26    D27      ChromaDB vs Qdrant 비교
# 27    D28  Contextual Compression 개념
# 28    D29    Self-Query Retriever 원리
# 29    D30     Multi-Hop Retrieval 예시
#
#                                               content author  \
# 0   제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(...    김민수
# 1   비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기...    이영희
# 2   걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹으로, 대표곡으로는 “Somet...    박지훈
# 3   세종대왕(1397~1450)은 훈민정음을 창제하여 한글을 보급한 조선의 4대 임금입...    최수정
# 4   이순신 장군(1545~1598)은 임진왜란 당시 명량 해전에서 13척의 배로 133...    정우성
# 5   2024년 전 지구 평균 기온은 산업화 이전 대비 약 1.2℃ 상승했으며, 해수면 ...    한예슬
# 6   최근 인공지능 분야에서는 생성형 AI, 멀티모달 모델, 강화학습 기반 에이전트 개발...   강다니엘
# 7   서울 지하철은 1호선부터 9호선까지 운행되며, 주요 환승역으로는 서울역·강남역·종로...    오정연
# 8   판소리는 소리꾼과 고수가 함께 공연하는 한국 전통 음악으로, 대표 작품에는 “춘향가...    신동엽
# 9   한국 축구 대표팀은 2002 한일 월드컵 4강 진출, 2012 런던 올림픽 동메달 ...    윤아름
# 10  건강을 위해서는 규칙적 식습관, 적절한 운동(주 3회 이상, 유산소+근력), 충분한...    김민수
# 11  서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, ...    이영희
# 12  비빔밥은 지역별로 칼로리, 탄수화물, 단백질, 지방 함량이 차이를 보입니다. 전주 ...    박지훈
# 13  AI를 활용한 기후 예측 연구는 기계학습 모델을 통해 대규모 기상 데이터를 분석해 ...    최수정
# 14  가야금은 한국 전통 현악기로, 12개의 줄을 가진 칠현금(七絃琴) 계열 악기입니다....    정우성
# 15  전통 혼례는 예식 절차가 복잡하며, 폐백, 예단, 함, 폐백음식 등 여러 의례가 포...    한예슬
# 16  2023년 한국 영화 흥행 순위 Top10에는 “헌트”, “비상선언”, “범죄도시3...   강다니엘
# 17  윈도우즈 환경에서 한글이 깨지지 않고 시각화(그래프·차트)할 때는, 한글 폰트를 시...    오정연
# 18  코드 악취(Bad Smell)는 설계·구현 단계에서 코드 구조가 비효율적이거나 유지...    신동엽
# 19  JUnit5는 모듈화된 구조(Java Platform Module System 지원...    윤아름
# 20  Wheel of Fortune은 랜덤으로 숫자·문자가 배치된 원판을 돌려 맞춰진 알...    김민수
# 21  싱글톤(Singleton) 패턴은 클래스의 인스턴스를 한 개만 생성하도록 보장하며,...    이영희
# 22  Strategy 패턴은 알고리즘 군을 캡슐화하여 상호 교환 가능하도록 만드는 패턴입...    박지훈
# 23  Command 패턴은 요청을 객체로 캡슐화하여 요청을 매개변수화하고, 호출자(inv...    최수정
# 24  2025년 한국 정부는 “AI 국가전략 2.0”을 발표하며, 인공지능 기술 연구·개...    정우성
# 25  딥러닝 모델(예: LSTM, Transformer 기반 시계열 모델)을 활용한 기상...    한예슬
# 26  ChromaDB와 Qdrant는 벡터 검색 라이브러리로, ChromaDB는 오픈소스...   강다니엘
# 27  Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 압축(...    오정연
# 28  Self-Query Retriever는 문서 메타데이터(제목·요약·키워드)를 분석해...    신동엽
# 29  Multi-Hop Retrieval은 한 단계의 검색으로 해결되지 않는 복합 질문에...    윤아름
#
#              category
# 0                  여행
# 1                  음식
# 2               문화;음악
# 3               역사;교육
# 4               역사;군사
# 5           환경;과학;보고서
# 6            기술;윤리;AI
# 7               교통;여행
# 8            문화;음악;역사
# 9              스포츠;역사
# 10              건강;생활
# 11              여행;레저
# 12           음식;영양;건강
# 13           기술;환경;과학
# 14           문화;음악;역사
# 15           문화;역사;의식
# 16       문화;영화;엔터테인먼트
# 17        기술;소프트웨어;설치
# 18  기술;프로그래밍;소프트웨어 개발
# 19       기술;프로그래밍;테스팅
# 20       게임;엔터테인먼트;기술
# 21  기술;프로그래밍;소프트웨어 개발
# 22  기술;프로그래밍;소프트웨어 개발
# 23  기술;프로그래밍;소프트웨어 개발
# 24          정책;기술;보고서
# 25           기술;과학;환경
# 26       기술;데이터베이스;비교
# 27           기술;AI;검색
# 28           기술;AI;검색
# 29           기술;AI;검색

# %%
queries_df = pd.read_csv('queries_meta_v2.csv')
queries_df
# Out:
#    query_id                       query_text  \
# 0       Q01               저자 김민수의 문서를 모두 보여줘
# 1       Q02               저자 이영희의 문서를 모두 보여줘
# 2       Q03               저자 박지훈의 문서를 모두 보여줘
# 3       Q04               저자 최수정의 문서를 모두 보여줘
# 4       Q05               저자 정우성의 문서를 모두 보여줘
# 5       Q06               저자 한예슬의 문서를 모두 보여줘
# 6       Q07              저자 강다니엘의 문서를 모두 보여줘
# 7       Q08               저자 오정연의 문서를 모두 보여줘
# 8       Q09               저자 신동엽의 문서를 모두 보여줘
# 9       Q10               저자 윤아름의 문서를 모두 보여줘
# 10      Q11            카테고리 AI에 해당하는 문서를 찾아줘
# 11      Q12            카테고리 건강에 해당하는 문서를 찾아줘
# 12      Q13            카테고리 검색에 해당하는 문서를 찾아줘
# 13      Q14            카테고리 게임에 해당하는 문서를 찾아줘
# 14      Q15            카테고리 과학에 해당하는 문서를 찾아줘
# 15      Q16            카테고리 교육에 해당하는 문서를 찾아줘
# 16      Q17            카테고리 교통에 해당하는 문서를 찾아줘
# 17      Q18            카테고리 군사에 해당하는 문서를 찾아줘
# 18      Q19            카테고리 기술에 해당하는 문서를 찾아줘
# 19      Q20        카테고리 데이터베이스에 해당하는 문서를 찾아줘
# 20      Q21     저자 김민수이(가) 쓴 게임 카테고리 문서를 보여줘
# 21      Q22  저자 이영희이(가) 쓴 프로그래밍 카테고리 문서를 보여줘
# 22      Q23     저자 박지훈이(가) 쓴 음식 카테고리 문서를 보여줘
# 23      Q24     저자 최수정이(가) 쓴 환경 카테고리 문서를 보여줘
# 24      Q25     저자 정우성이(가) 쓴 음악 카테고리 문서를 보여줘
# 25      Q26          카테고리가 AI이거나 건강인 문서를 보여줘
# 26      Q27          카테고리가 건강이거나 검색인 문서를 보여줘
# 27      Q28          카테고리가 검색이거나 게임인 문서를 보여줘
# 28      Q29          카테고리가 게임이거나 과학인 문서를 보여줘
# 29      Q30          카테고리가 과학이거나 교육인 문서를 보여줘
#
#                                   relevant_doc_ids
# 0                                 D1=1;D11=1;D21=1
# 1                                 D2=1;D12=1;D22=1
# 2                                 D3=1;D13=1;D23=1
# 3                                 D4=1;D14=1;D24=1
# 4                                 D5=1;D15=1;D25=1
# 5                                 D6=1;D16=1;D26=1
# 6                                 D7=1;D17=1;D27=1
# 7                                 D8=1;D18=1;D28=1
# 8                                 D9=1;D19=1;D29=1
# 9                                D10=1;D20=1;D30=1
# 10                          D7=1;D28=1;D29=1;D30=1
# 11                                     D11=1;D13=1
# 12                               D28=1;D29=1;D30=1
# 13                                           D21=1
# 14                                D6=1;D14=1;D26=1
# 15                                            D4=1
# 16                                            D8=1
# 17                                            D5=1
# 18  D7=1;D14=1;D18=1;D19=1;D20=1;D21=1;D22=1;D23=1
# 19                                           D27=1
# 20                                           D21=1
# 21                                           D22=1
# 22                                           D13=1
# 23                                           D14=1
# 24                                           D15=1
# 25              D7=1;D11=1;D13=1;D28=1;D29=1;D30=1
# 26                   D11=1;D13=1;D28=1;D29=1;D30=1
# 27                         D21=1;D28=1;D29=1;D30=1
# 28                          D6=1;D14=1;D21=1;D26=1
# 29                           D4=1;D6=1;D14=1;D26=1

# %%
from pinecone import Pinecone, ServerlessSpec  # Pinecone 클라이언트, 인덱스 스펙설정

pc = Pinecone()
print(pc.list_indexes().names())  # 인덱스 이름

# 인덱스명 ir
if 'ir-meta' not in pc.list_indexes().names():
    # 없으면 인덱스 생성
    pc.create_index(
        name = 'ir-meta',
        dimension = 1536,
        metric = 'cosine',          # 유사도 기준
        spec = ServerlessSpec(
            region = 'us-east-1',
            cloud = 'aws'
        )
    )
    print('ir-meta 인덱스 생성 완료!')
else:
    print('ir-meta 인덱스 이미 존재!')
# Out:
# []
# ir-meta 인덱스 생성 완료!

# %%
from langchain_openai import OpenAIEmbeddings
from langchain_pinecone import PineconeVectorStore

embeddings = OpenAIEmbeddings(model='text-embedding-3-small')  # 1536차원 임베딩 모델

vector_store = PineconeVectorStore(
    index_name = 'ir-meta', # 연결할 index명
    embedding = embeddings  # 사용할 임베딩 함수 (연결할 인덱스 차원과 임베딩차원이 같아야 함)
)

# %% [markdown]
# ## Document Upsert
# - 임베딩 변환할 텍스트 외의 컬럼은 metadata 속성(dict)안에 저장이 되어 있어야 검색에 활용할 수 있다.

# %%
# 압축문서를 Document 변환 후에 Pinecone 업서트
# DataFrame -> Langchain Document 변환
from langchain_core.documents import Document  # Langchain 문서 객체
from tqdm.auto import tqdm
from pprint import pprint

docs_to_index = []

for idx, row in tqdm(document_df.iterrows()):  # compressed_df을 행 단위로 순회
    categories = row['category'].split(';')    # 카테고리 컬럼 값은 ; 기준으로 리스트로 분리
    metadata = {
        'doc_id': row['doc_id'],  # 문서 ID 추출
        'title': row['title'],    # 문서 제목 추출
        'author': row['author'],
        'category': categories
    }
    doc = Document(
        page_content = row['content'],
        metadata = metadata
    )
    
    docs_to_index.append(doc)   # 리스트에 추가

pprint(docs_to_index)
# Out:
# 0it [00:00, ?it/s]
# [Document(metadata={'doc_id': 'D1', 'title': '제주도 여행 가이드', 'author': '김민수', 'category': ['여행']}, page_content='제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(...'),
#  Document(metadata={'doc_id': 'D2', 'title': '전주 비빔밥과 진주 비빔밥 차이점', 'author': '이영희', 'category': ['음식']}, page_content='비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기...'),
#  Document(metadata={'doc_id': 'D3', 'title': '걸스데이 히트곡 분석', 'author': '박지훈', 'category': ['문화', '음악']}, page_content='걸스데이는 2010년 데뷔한 대한민국의 4인조 걸그룹으로, 대표곡으로는 “Somet...'),
#  Document(metadata={'doc_id': 'D4', 'title': '세종대왕과 훈민정음', 'author': '최수정', 'category': ['역사', '교육']}, page_content='세종대왕(1397~1450)은 훈민정음을 창제하여 한글을 보급한 조선의 4대 임금입...'),
#  Document(metadata={'doc_id': 'D5', 'title': '이순신 장군의 명량 해전', 'author': '정우성', 'category': ['역사', '군사']}, page_content='이순신 장군(1545~1598)은 임진왜란 당시 명량 해전에서 13척의 배로 133...'),
#  Document(metadata={'doc_id': 'D6', 'title': '2024년 기후 변화 종합 보고서', 'author': '한예슬', 'category': ['환경', '과학', '보고서']}, page_content='2024년 전 지구 평균 기온은 산업화 이전 대비 약 1.2℃ 상승했으며, 해수면 ...'),
#  Document(metadata={'doc_id': 'D7', 'title': 'AI 기술 동향 및 윤리', 'author': '강다니엘', 'category': ['기술', '윤리', 'AI']}, page_content='최근 인공지능 분야에서는 생성형 AI, 멀티모달 모델, 강화학습 기반 에이전트 개발...'),
#  Document(metadata={'doc_id': 'D8', 'title': '서울 지하철 이용 가이드', 'author': '오정연', 'category': ['교통', '여행']}, page_content='서울 지하철은 1호선부터 9호선까지 운행되며, 주요 환승역으로는 서울역·강남역·종로...'),
#  Document(metadata={'doc_id': 'D9', 'title': '판소리 “춘향가” 서사 구조', 'author': '신동엽', 'category': ['문화', '음악', '역사']}, page_content='판소리는 소리꾼과 고수가 함께 공연하는 한국 전통 음악으로, 대표 작품에는 “춘향가...'),
#  Document(metadata={'doc_id': 'D10', 'title': '한국 축구 대표팀 주요 기록', 'author': '윤아름', 'category': ['스포츠', '역사']}, page_content='한국 축구 대표팀은 2002 한일 월드컵 4강 진출, 2012 런던 올림픽 동메달 ...'),
#  Document(metadata={'doc_id': 'D11', 'title': '건강한 생활습관 가이드', 'author': '김민수', 'category': ['건강', '생활']}, page_content='건강을 위해서는 규칙적 식습관, 적절한 운동(주 3회 이상, 유산소+근력), 충분한...'),
#  Document(metadata={'doc_id': 'D12', 'title': '서울 근교 당일치기 여행지', 'author': '이영희', 'category': ['여행', '레저']}, page_content='서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, ...'),
#  Document(metadata={'doc_id': 'D13', 'title': '전국 비빔밥 영양 성분 분석', 'author': '박지훈', 'category': ['음식', '영양', '건강']}, page_content='비빔밥은 지역별로 칼로리, 탄수화물, 단백질, 지방 함량이 차이를 보입니다. 전주 ...'),
#  Document(metadata={'doc_id': 'D14', 'title': 'AI 기반 기후 예측 연구 사례', 'author': '최수정', 'category': ['기술', '환경', '과학']}, page_content='AI를 활용한 기후 예측 연구는 기계학습 모델을 통해 대규모 기상 데이터를 분석해 ...'),
#  Document(metadata={'doc_id': 'D15', 'title': '한국 전통 음악 “가야금”', 'author': '정우성', 'category': ['문화', '음악', '역사']}, page_content='가야금은 한국 전통 현악기로, 12개의 줄을 가진 칠현금(七絃琴) 계열 악기입니다....'),
#  Document(metadata={'doc_id': 'D16', 'title': '한국 전통 혼례 풍습', 'author': '한예슬', 'category': ['문화', '역사', '의식']}, page_content='전통 혼례는 예식 절차가 복잡하며, 폐백, 예단, 함, 폐백음식 등 여러 의례가 포...'),
#  Document(metadata={'doc_id': 'D17', 'title': '2023년 한국 영화 흥행 Top10', 'author': '강다니엘', 'category': ['문화', '영화', '엔터테인먼트']}, page_content='2023년 한국 영화 흥행 순위 Top10에는 “헌트”, “비상선언”, “범죄도시3...'),
#  Document(metadata={'doc_id': 'D18', 'title': '윈도우즈에서 한글 시각화 설정 방법', 'author': '오정연', 'category': ['기술', '소프트웨어', '설치']}, page_content='윈도우즈 환경에서 한글이 깨지지 않고 시각화(그래프·차트)할 때는, 한글 폰트를 시...'),
#  Document(metadata={'doc_id': 'D19', 'title': '코드 악취와 리팩토링 개요', 'author': '신동엽', 'category': ['기술', '프로그래밍', '소프트웨어 개발']}, page_content='코드 악취(Bad Smell)는 설계·구현 단계에서 코드 구조가 비효율적이거나 유지...'),
#  Document(metadata={'doc_id': 'D20', 'title': 'JUnit5와 JUnit4 차이점', 'author': '윤아름', 'category': ['기술', '프로그래밍', '테스팅']}, page_content='JUnit5는 모듈화된 구조(Java Platform Module System 지원...'),
#  Document(metadata={'doc_id': 'D21', 'title': 'Wheel of Fortune 게임 구조', 'author': '김민수', 'category': ['게임', '엔터테인먼트', '기술']}, page_content='Wheel of Fortune은 랜덤으로 숫자·문자가 배치된 원판을 돌려 맞춰진 알...'),
#  Document(metadata={'doc_id': 'D22', 'title': '싱글톤 디자인 패턴 예제', 'author': '이영희', 'category': ['기술', '프로그래밍', '소프트웨어 개발']}, page_content='싱글톤(Singleton) 패턴은 클래스의 인스턴스를 한 개만 생성하도록 보장하며,...'),
#  Document(metadata={'doc_id': 'D23', 'title': 'Strategy 패턴 설명', 'author': '박지훈', 'category': ['기술', '프로그래밍', '소프트웨어 개발']}, page_content='Strategy 패턴은 알고리즘 군을 캡슐화하여 상호 교환 가능하도록 만드는 패턴입...'),
#  Document(metadata={'doc_id': 'D24', 'title': 'Command 패턴 적용 사례', 'author': '최수정', 'category': ['기술', '프로그래밍', '소프트웨어 개발']}, page_content='Command 패턴은 요청을 객체로 캡슐화하여 요청을 매개변수화하고, 호출자(inv...'),
#  Document(metadata={'doc_id': 'D25', 'title': '2025년 한국 AI 정책 보고서', 'author': '정우성', 'category': ['정책', '기술', '보고서']}, page_content='2025년 한국 정부는 “AI 국가전략 2.0”을 발표하며, 인공지능 기술 연구·개...'),
#  Document(metadata={'doc_id': 'D26', 'title': '딥러닝 기반 기상 예측 모델', 'author': '한예슬', 'category': ['기술', '과학', '환경']}, page_content='딥러닝 모델(예: LSTM, Transformer 기반 시계열 모델)을 활용한 기상...'),
#  Document(metadata={'doc_id': 'D27', 'title': 'ChromaDB vs Qdrant 비교', 'author': '강다니엘', 'category': ['기술', '데이터베이스', '비교']}, page_content='ChromaDB와 Qdrant는 벡터 검색 라이브러리로, ChromaDB는 오픈소스...'),
#  Document(metadata={'doc_id': 'D28', 'title': 'Contextual Compression 개념', 'author': '오정연', 'category': ['기술', 'AI', '검색']}, page_content='Contextual Compression은 긴 텍스트에서 핵심 정보만 추출해 압축(...'),
#  Document(metadata={'doc_id': 'D29', 'title': 'Self-Query Retriever 원리', 'author': '신동엽', 'category': ['기술', 'AI', '검색']}, page_content='Self-Query Retriever는 문서 메타데이터(제목·요약·키워드)를 분석해...'),
#  Document(metadata={'doc_id': 'D30', 'title': 'Multi-Hop Retrieval 예시', 'author': '윤아름', 'category': ['기술', 'AI', '검색']}, page_content='Multi-Hop Retrieval은 한 단계의 검색으로 해결되지 않는 복합 질문에...')]

# %%
# Documents를 Pinecone에 업서트
vector_store.add_documents(docs_to_index)
# Out:
# ['204cc876-cc4f-42d3-9e1b-d70f4e1b0675',
#  '7b2d50c2-5614-47c1-9fc1-e9a6c5bc2c5a',
#  'ed50f829-883f-49e7-bf1d-9a71ce66fca2',
#  '2b4c5409-d7cd-480e-a426-73b3c2971de0',
#  '8e3dd396-6c39-4491-9ea9-530f6b0807c6',
#  'e7ebb8b5-874b-4f47-9c72-7b5444902031',
#  '2db5d001-d077-4af6-b430-1246b274ad27',
#  'bed9f03f-bdf5-4b75-b828-9f98d32f6f9f',
#  'c9ea0042-919e-42a4-becd-aa7270d7c84c',
#  'b86468e2-dd51-46e2-b1f7-4fe41a077b5d',
#  'a065adf0-2a10-43a1-9c6d-c5401b3bebf3',
#  'c2a5bfd4-5d01-4eb9-b800-79d603912376',
#  '2364da00-4b2d-4134-89cb-bc8772eb0568',
#  'c14db94c-98fd-49f7-a1b2-19349a1ae7ed',
#  '3bf703c9-ac9e-4f76-a64e-7bb169804761',
#  '20683757-f59f-4e2a-922b-8ee10cfdbade',
#  'd4f19da2-443d-44be-8469-393ca34a0613',
#  '5c6fbeb8-b6f0-4d56-93b7-67bd49437207',
#  'a79633a3-7342-464d-9ced-1f7ce39c1e53',
#  '0693a272-b876-4acb-82e8-3f7df32de168',
#  'd92fa329-1892-4cc5-9fba-8ddf3fcf8829',
#  'c2247678-0265-4111-b2fa-0a4477e47c8b',
#  'af75a40c-cfd5-411c-913d-614ac91ed36c',
#  '8c4a7277-2d48-493e-8155-735b4b0eeb6c',
#  'e931ebf0-170a-4049-b124-f7ca9c23f4af',
#  '6e7f2333-4185-452c-9270-8367f3e1b896',
#  'd16d4922-bb86-43f8-bbd4-0d1620a7696f',
#  '921d7460-be7f-4375-9f26-8431c25ae36f',
#  '52cb1554-3d25-427d-8774-4d380fde93ef',
#  '8bb70ab1-c868-4069-b1fb-f4a728b9e29a']

# %% [markdown]
# ## 메타데이터 필터를 사용한 벡터 검색
#
# https://python.langchain.com/docs/integrations/vectorstores/
#
# LangChain의 `vectorstore.similarity_search`에서 **filter**를 사용하는 방법은 벡터스토어 종류에 따라 약간 다르지만, 기본적으로 **문서의 메타데이터(metadata)를 조건으로 검색 결과를 제한**하는 데 사용한다.
#
# **고급 필터링 (MongoDB 스타일 연산자)**
#
# 몇몇 벡터스토어(예: FAISS, Chroma 등)는 **MongoDB 스타일의 연산자**를 지원한다. 예를 들어, 특정 값과 일치하는 것뿐만 아니라, 크거나, 작거나, 리스트 내 포함 등 다양한 조건을 줄 수 있다.
#
# 지원 연산자 예시:
# - `$eq`: 같음
# - `$neq`: 같지 않음
# - `$gt`: 큼
# - `$lt`: 작음
# - `$gte`: 크거나 같음
# - `$lte`: 작거나 같음
# - `$in`: 리스트 내 포함
# - `$nin`: 리스트 내 미포함
# - `$and`, `$or`, `$not`: 논리 연산

# %%
query = ''  # 빈 쿼리(필터로만 검색)
results = vector_store.similarity_search(
    query,
    k = 5,
    filter = {
        'category': {
            '$in': ['역사', '여행']  # category가 역사나 여행인 문서 검색
        }
    }
)

for doc in results:
    print(f"doc_id : {doc.metadata['doc_id']}, category : {doc.metadata['category']}")
    print(f"doc_title : {doc.metadata['title']}")
    print(doc.page_content)
    print()
# Out:
# doc_id : D4, category : ['역사', '교육']
# doc_title : 세종대왕과 훈민정음
# 세종대왕(1397~1450)은 훈민정음을 창제하여 한글을 보급한 조선의 4대 임금입...
#
# doc_id : D1, category : ['여행']
# doc_title : 제주도 여행 가이드
# 제주도는 대한민국의 대표 관광지로서, 한라산 등반, 성산 일출봉 관광, 해변 활동(...
#
# doc_id : D9, category : ['문화', '음악', '역사']
# doc_title : 판소리 “춘향가” 서사 구조
# 판소리는 소리꾼과 고수가 함께 공연하는 한국 전통 음악으로, 대표 작품에는 “춘향가...
#
# doc_id : D12, category : ['여행', '레저']
# doc_title : 서울 근교 당일치기 여행지
# 서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, ...
#
# doc_id : D16, category : ['문화', '역사', '의식']
# doc_title : 한국 전통 혼례 풍습
# 전통 혼례는 예식 절차가 복잡하며, 폐백, 예단, 함, 폐백음식 등 여러 의례가 포...

# %%
query = ''  # 빈 쿼리(필터로만 검색)
results = vector_store.similarity_search(
    query,
    k = 5,
    filter = {
        'author': {
            '$eq': '이영희'  # 저자가 이영희인 문서 검색
        }
    }
)

for doc in results:
    print(f"doc_id : {doc.metadata['doc_id']}, category : {doc.metadata['category']}")
    print(f"doc_title : {doc.metadata['title']}, author : {doc.metadata['author']}")
    print(doc.page_content)
    print()
# Out:
# doc_id : D22, category : ['기술', '프로그래밍', '소프트웨어 개발']
# doc_title : 싱글톤 디자인 패턴 예제, author : 이영희
# 싱글톤(Singleton) 패턴은 클래스의 인스턴스를 한 개만 생성하도록 보장하며,...
#
# doc_id : D2, category : ['음식']
# doc_title : 전주 비빔밥과 진주 비빔밥 차이점, author : 이영희
# 비빔밥은 조선 시대부터 전해 내려온 대표적 한국 음식으로, 밥 위에 고명(채소·고기...
#
# doc_id : D12, category : ['여행', '레저']
# doc_title : 서울 근교 당일치기 여행지, author : 이영희
# 서울 근교에서 당일치기로 다녀올 만한 여행지로는 가평 쁘띠프랑스, 남양주 수종사, ...

# %% [markdown]
# ## SelfQueryRetriever
#
# **SelfQueryRetriever**는 사용자의 자연어 질문을 분석하여 쿼리 자체에 포함된 **메타데이터 필터**와 **벡터 검색용 쿼리**를 분리하여 실행하는 검색 방식이다.
#
# 일반적인 벡터 검색은 질문의 '의미'만으로 데이터를 찾지만, SelfQueryRetriever는 LLM을 활용해 질문에서 조건(필터)을 추출한다.
#
# **1. 작동 원리**
#
# 사용자가 "2023년 이후에 개봉한 평점 8.5 이상의 SF 영화 찾아줘"라고 질문하면, SelfQueryRetriever는 내부적으로 다음과 같은 과정을 거친다.
#
# 1. **질문 분석**: LLM이 질문을 해석하여 검색어(Query)와 필터 조건(Metadata Filter)을 생성한다.
# * **검색어**: "SF 영화"
# * **필터**: `release_year > 2023 AND rating >= 8.5`
#
#
# 2. **쿼리 실행**: 생성된 필터를 벡터 데이터베이스(Vector DB)의 메타데이터에 적용함과 동시에 검색어로 유사도 검색을 수행한다.
# 3. **결과 반환**: 두 조건이 모두 충족된 결과물만 사용자에게 전달한다.
#
# **2. 주요 구성 요소**
#
# | 구성 요소 | 설명 |
# | --- | --- |
# | **Document Content Description** | 데이터셋이 어떤 내용을 담고 있는지 LLM에게 설명하는 텍스트이다. |
# | **Metadata Field Info** | 각 메타데이터 필드의 이름, 타입(정수, 문자열 등), 의미를 정의한 정보이다. |
# | **LLM** | 자연어 질문을 구조화된 쿼리(필터)로 변환하는 역할을 한다. |
# | **Vector Store** | 실제 데이터와 메타데이터가 저장된 저장소이다. |
#
# **3. 왜 사용하는가?**
#
# * **정확도 향상**: "최근에 나온"이나 "특정 점수 이상" 같은 정량적 조건은 의미론적 유사성만으로는 정확히 필터링하기 어렵다. 이를 논리적 필터로 처리함으로써 검색 결과의 신뢰도를 높인다.
# * **자연스러운 인터페이스**: 사용자가 SQL이나 복잡한 필터 문법을 배울 필요 없이, 일상적인 언어로 정교한 검색이 가능하다.
# * **효율성**: 불필요한 데이터를 벡터 검색 단계에서 미리 배제하여 검색 범위를 좁힐 수 있다.

# %%
from langchain.chat_models import init_chat_model
from langchain_classic.retrievers import SelfQueryRetriever
from langchain_classic.chains.query_constructor.schema import AttributeInfo  # 메타데이터 필드 정의
from langchain_classic.retrievers.self_query.pinecone import PineconeTranslator  # Pinecone 필터 변환기

llm = init_chat_model('gpt-5.6-luna', temperature = 0)

# 검색에 활용할 메타데이터
metadata_field_info = [
    AttributeInfo(name='doc_id', type='string', description='문서 식별 번호'),
    AttributeInfo(name='author', type='string', description='문서를 작성한 저자 이름'),
    AttributeInfo(name='category', type='list[string]', description='문서의 분류 목록'),
    AttributeInfo(name='title', type='string', description='문서 제목')
]

document_content_description = '다양한 분류의 텍스트 데이터셋'  # 문서 설명

self_query_retriever = SelfQueryRetriever.from_llm(
    llm = llm,
    vectorstore = vector_store,
    document_contents = document_content_description,
    metadata_field_info = metadata_field_info,
    structured_query_translator = PineconeTranslator()  # Pinecone 필터 변환
)

# %% [markdown]
# ### 메타데이터 필터링 수행

# %%
from tqdm.auto import tqdm

results_list = []  # DataFrame 시각화용
self_query_results = {}  # {qid: [doc_id, ...], ...}

for idx, row in tqdm(queries_df.iterrows(), total=len(queries_df)):  # queries_df 행 단위로 순회
    qid = row['query_id']      # 문서 ID 추출
    query_text = row['query_text']    # 문서 본문 추출
    docs = self_query_retriever.invoke(query_text)  # Self-Query 기반 검색 실행
    # LLM이 생성한 구조화 쿼리
    structured_query = self_query_retriever.query_constructor.invoke({'query': query_text})
    self_query_results[qid] = [doc.metadata['doc_id'] for doc in docs[:5]]

    # DataFrame 시각화용 결과
    results_list.append({
        'query_id': qid,
        'query_text': query_text,
        'structured_query': str(structured_query),
        'retrieved_doc_ids': self_query_results[qid]
    })
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
pd.set_option('display.max_colwidth', None)  # 긴 텍스트 컬럼 생략 해제

results_df = pd.DataFrame(results_list)
results_df
# Out:
#    query_id                       query_text  \
# 0       Q01               저자 김민수의 문서를 모두 보여줘
# 1       Q02               저자 이영희의 문서를 모두 보여줘
# 2       Q03               저자 박지훈의 문서를 모두 보여줘
# 3       Q04               저자 최수정의 문서를 모두 보여줘
# 4       Q05               저자 정우성의 문서를 모두 보여줘
# 5       Q06               저자 한예슬의 문서를 모두 보여줘
# 6       Q07              저자 강다니엘의 문서를 모두 보여줘
# 7       Q08               저자 오정연의 문서를 모두 보여줘
# 8       Q09               저자 신동엽의 문서를 모두 보여줘
# 9       Q10               저자 윤아름의 문서를 모두 보여줘
# 10      Q11            카테고리 AI에 해당하는 문서를 찾아줘
# 11      Q12            카테고리 건강에 해당하는 문서를 찾아줘
# 12      Q13            카테고리 검색에 해당하는 문서를 찾아줘
# 13      Q14            카테고리 게임에 해당하는 문서를 찾아줘
# 14      Q15            카테고리 과학에 해당하는 문서를 찾아줘
# 15      Q16            카테고리 교육에 해당하는 문서를 찾아줘
# 16      Q17            카테고리 교통에 해당하는 문서를 찾아줘
# 17      Q18            카테고리 군사에 해당하는 문서를 찾아줘
# 18      Q19            카테고리 기술에 해당하는 문서를 찾아줘
# 19      Q20        카테고리 데이터베이스에 해당하는 문서를 찾아줘
# 20      Q21     저자 김민수이(가) 쓴 게임 카테고리 문서를 보여줘
# 21      Q22  저자 이영희이(가) 쓴 프로그래밍 카테고리 문서를 보여줘
# 22      Q23     저자 박지훈이(가) 쓴 음식 카테고리 문서를 보여줘
# 23      Q24     저자 최수정이(가) 쓴 환경 카테고리 문서를 보여줘
# 24      Q25     저자 정우성이(가) 쓴 음악 카테고리 문서를 보여줘
# 25      Q26          카테고리가 AI이거나 건강인 문서를 보여줘
# 26      Q27          카테고리가 건강이거나 검색인 문서를 보여줘
# 27      Q28          카테고리가 검색이거나 게임인 문서를 보여줘
# 28      Q29          카테고리가 게임이거나 과학인 문서를 보여줘
# 29      Q30          카테고리가 과학이거나 교육인 문서를 보여줘
#
#                                                                                                                                                                                                                                        structured_query  \
# 0                                                                                                                                                                                                                      query=' ' filter=None limit=None
# 1                                                                                                                                                                                                                      query=' ' filter=None limit=None
# 2                                                                                                                                             query=' ' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='박지훈') limit=None
# 3                                                                                                                                                                                                                      query=' ' filter=None limit=None
# 4                                                                                                                                             query=' ' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='정우성') limit=None
# 5                                                                                                                                             query=' ' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='한예슬') limit=None
# 6                                                                                                                                            query=' ' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='강다니엘') limit=None
# 7                                                                                                                                                                                                                      query=' ' filter=None limit=None
# 8                                                                                                                                                                                                                      query=' ' filter=None limit=None
# 9                                                                                                                                             query=' ' filter=Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='윤아름') limit=None
# 10                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 11                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 12                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 13                                                                                                                                           query=' ' filter=Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='게임') limit=None
# 14                                                                                                                                           query=' ' filter=Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='과학') limit=None
# 15                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 16                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 17                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 18                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 19                                                                                                                                                                                                                query='데이터베이스' filter=None limit=None
# 20                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 21  query=' ' filter=Operation(operator=<Operator.AND: 'and'>, arguments=[Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='이영희'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='프로그래밍')]) limit=None
# 22     query=' ' filter=Operation(operator=<Operator.AND: 'and'>, arguments=[Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='박지훈'), Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='category', value='음식')]) limit=None
# 23     query=' ' filter=Operation(operator=<Operator.AND: 'and'>, arguments=[Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='최수정'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='환경')]) limit=None
# 24     query=' ' filter=Operation(operator=<Operator.AND: 'and'>, arguments=[Comparison(comparator=<Comparator.EQ: 'eq'>, attribute='author', value='정우성'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='음악')]) limit=None
# 25      query=' ' filter=Operation(operator=<Operator.OR: 'or'>, arguments=[Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='AI'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='건강')]) limit=None
# 26                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 27                                                                                                                                                                                                                     query=' ' filter=None limit=None
# 28      query=' ' filter=Operation(operator=<Operator.OR: 'or'>, arguments=[Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='게임'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='과학')]) limit=None
# 29      query=' ' filter=Operation(operator=<Operator.OR: 'or'>, arguments=[Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='과학'), Comparison(comparator=<Comparator.IN: 'in'>, attribute='category', value='교육')]) limit=None
#
#        retrieved_doc_ids
# 0         [D21, D11, D1]
# 1   [D17, D28, D16, D22]
# 2         [D3, D23, D13]
# 3         [D24, D14, D4]
# 4         [D25, D15, D5]
# 5   [D17, D28, D16, D22]
# 6         [D17, D27, D7]
# 7         [D28, D18, D8]
# 8         [D9, D19, D29]
# 9   [D17, D28, D16, D22]
# 10   [D28, D29, D7, D30]
# 11  [D17, D28, D16, D22]
# 12  [D28, D17, D16, D22]
# 13  [D28, D17, D16, D22]
# 14  [D28, D17, D16, D22]
# 15                  [D4]
# 16  [D28, D17, D16, D22]
# 17  [D28, D17, D16, D22]
# 18  [D28, D22, D26, D25]
# 19  [D28, D17, D16, D22]
# 20  [D28, D17, D16, D22]
# 21                 [D22]
# 22                 [D13]
# 23                 [D14]
# 24                 [D15]
# 25   [D28, D29, D11, D7]
# 26  [D28, D29, D11, D13]
# 27  [D28, D21, D29, D30]
# 28  [D28, D17, D16, D22]
# 29  [D28, D17, D16, D22]

# %%
import numpy as np

def parse_relevant(relevant_str) -> dict[str, int]:
    """
    참조문서 답안 문자열을 dict로 파싱하는 함수

    relevant_str = "D1=3;D4=1;D30=1" -> {'D1': 3, 'D4': 1, 'D30': 1}
    """
    pairs = relevant_str.split(';')  # ';' 기준으로 분리
    rel_dict = {}       # {doc_id: grade, ...}
    for pair in pairs:
        doc_id, grade = pair.split('=')  # '=' 기준으로 분리
        rel_dict[doc_id] = int(grade)    # {doc_id: grade, ...} 
    return rel_dict

# 예측 결과와 실제 정답을 비교해서 평가지표를 계산하는 함수
def compute_metrics(predicted, relevant_dict, k=5) -> tuple[float, float, float, float]:
    # Precision@k
    hits = sum([1 for doc in predicted[:k] if doc in relevant_dict])  # top-k 적중 개수
    precision = hits / k  # 정밀도 = 맞춘갯수 / 전체갯수

    # Recall@k
    total_relevant = len(relevant_dict)  # 전체 관련 문서 수
    recall = hits / total_relevant if total_relevant > 0 else 0  # 재현율 = 관련 문서 맞춘 수

    # MRR : 예측치 중 첫 관련문서 순위 점수
    rr = 0  # 관련 문서 수
    # 전체 랭킹에서 첫번째 적중된 것을 찾음
    for idx, doc in enumerate(predicted):
        if doc in relevant_dict:
            rr = 1 / (idx + 1)  # 첫 적중 순위 역수
            break  # 첫 번째 적중 rr 반영 후 반복문 탈출
    
    # AP (MAP를 위한 사전 계산)
    num_correct = 0  # 현재까지의 적중 횟수
    precisions = []  # 적중시의 precision
    for idx, doc in enumerate(predicted[:k]):  # top-k 범위에서
        if doc in relevant_dict:
            num_correct += 1    # 적중시 1 누적
            precisions.append(num_correct / (idx + 1))  # 현재 시점의 precision 기록
    ap = np.mean(precisions) if precisions else 0  # pricision 평균치 사용, 없으면 0
    
    return precision, recall, rr, ap

# 여러 쿼리에 대한 평균 성능지표 계산하는 함수
def evaluate_all(method_results, queries_df, k=5):
    prec_list, rec_list, rr_list, ap_list = [], [], [], []  # 지표별 결과 저장

    for idx, row in queries_df.iterrows():
        qid = row['query_id']  # 쿼리 ID
        relevant_dict = parse_relevant(row['relevant_doc_ids'])  # 정답 dict 파싱
        predicted = method_results[qid]  # 해당 쿼리의 예측 랭킹
        p, r, rr, ap = compute_metrics(predicted, relevant_dict, k)  # 지표 계산
        prec_list.append(p)
        rec_list.append(r)
        rr_list.append(rr)
        ap_list.append(ap)
    
    return {
        'P@k': np.mean(prec_list),  # 쿼리 평균 Precision@k
        'R@k': np.mean(rec_list),   # 쿼리 평균 Recall@k
        'MRR': np.mean(rr_list),    # 쿼리 평균 MRR
        'MAP': np.mean(ap_list),    # 쿼리 평균 MAP
    }

# %% [markdown]
# ### 검색 수행

# %%
dense_results = {}  # {qid: [doc_id, ...], ...}

for idx, row in tqdm(queries_df.iterrows()):
    qid = row['query_id']
    query_text = row['query_text']
    docs = vector_store.similarity_search(query_text, k=5)  # 원본 벡터 서치
    dense_results[qid] = [doc.metadata['doc_id'] for doc in docs]
# Out:
# 0it [00:00, ?it/s]

# %%
dense_metrics = evaluate_all(dense_results, queries_df, k=5)
self_query_metrics = evaluate_all(self_query_results, queries_df, k=5)

# %%
metrics_df = pd.DataFrame({
    'Metrics': ['P@5', 'R@5', 'MRR', 'MAP'],  # 지표 이름
    'Dense': [dense_metrics['P@k'], dense_metrics['R@k'], dense_metrics['MRR'], dense_metrics['MAP']],
    'Metadata_Filtering': [self_query_metrics['P@k'], self_query_metrics['R@k'], self_query_metrics['MRR'], self_query_metrics['MAP']],
})

metrics_df
# Out:
#   Metrics     Dense  Metadata_Filtering
# 0     P@5  0.233333            0.306667
# 1     R@5  0.458889            0.553056
# 2     MRR  0.400000            0.602778
# 3     MAP  0.379259            0.602778

# %%
import matplotlib.pyplot as plt

metrics = ['P@5', 'R@5', 'MRR', 'MAP']
dense_vals = [dense_metrics['P@k'], dense_metrics['R@k'], dense_metrics['MRR'], dense_metrics['MAP']]
metadata_vals = [self_query_metrics['P@k'], self_query_metrics['R@k'], self_query_metrics['MRR'], self_query_metrics['MAP']]

x = range(len(metrics))  # 0~3

plt.figure(figsize=(8, 4))
plt.plot(x, dense_vals, marker='o', label='Dense')
plt.plot(x, metadata_vals, marker='s', label='Metadata-Filtering')
plt.xticks(x, metrics)  # x축 눈금은 0~3 -> 지표명
plt.ylim(0, 1.1)
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.title('Dense vs Metadata-Filtering')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## 왜 이런 결과가 나왔나?
#
# - **Dense Retrieval**
#   - 문서의 **의미적 유사도**만을 기준으로 판단
#   - 작성자(author), 카테고리(category)와 같은 **구조적 조건을 직접 반영하지 못함**
#
# - **Self-Query Retriever (Metadata 기반)**
#   - 자연어 질의에서 **조건을 자동으로 추출**
#   - 추출된 조건을 **메타데이터 필터로 강제 적용**하여 검색
#
# 예를 들어,
#
# > **“이영희가 쓴 여행 관련 글”**
#
# 과 같은 질의는
# - Dense Retrieval에게는 의미적으로 **모호한 질문**이지만
# - Metadata 검색에게는 **명확한 조건 기반 질의**가 된다.
#
# ---
#
# ## 실무 결론 (중요)
#
# ### 권장 검색 파이프라인
# Self-Query / Metadata Filtering
# ↓
# Dense Retrieval
# ↓
# ReRank (선택)
#
# - **조건이 명확한 질의** → Metadata 검색 우선
# - **의미적 탐색 중심 질의** → Dense Retrieval 활용
# - **실제 서비스 환경** → 두 방식을 결합한 Hybrid 전략 적용
#
# ---
#
# ## 한 줄 결론 (교안 / 발표용)
#
# > **구조적 조건이 포함된 질의에서는 Dense Retrieval보다 Metadata 기반 검색이 압도적으로 높은 정확도를 보인다.**
